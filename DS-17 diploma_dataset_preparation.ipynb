# %%
import pandas as pd
import os
import re
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data_set_1 = pd.read_csv('/Users/natalialogvinova/Desktop/DS diploma/DS-17 diploma/Raw_Jobs.csv', sep = ';')
print(data_set_1.shape)
# Out:
# (561989, 12)

# %%
data_set_1['key_skills'].values
# Out:
# array([nan, nan, nan, ...,
#        'Желание работать и зарабатывать,Быстрообучаемый,Физическая выносливость',
#        nan, nan], dtype=object)

# %%
def split_salary_column(df, salary_column, new_columns_prefix=''):
    """
    Разделяет столбец с зарплатой на три отдельных столбца.
    
    Parameters:
    df (DataFrame): Исходный датафрейм
    salary_column (str): Название столбца с зарплатой
    new_columns_prefix (str): Префикс для новых столбцов
    
    Returns:
    DataFrame: Дадафрейм с добавленными столбцами salary_from, salary_to, currency
    """
    
    # Создаем копию датафрейма
    result_df = data_set_1.copy()
    
    # Создаем новые столбцы
    result_df[f'{new_columns_prefix}salary_from'] = np.nan
    result_df[f'{new_columns_prefix}salary_to'] = np.nan
    result_df[f'{new_columns_prefix}currency'] = np.nan
    
    # Регулярные выражения для парсинга
    salary_pattern = r'от\s*(\d+[\d\s]*)\s*до\s*(\d+[\d\s]*)\s*([A-Z]{3})?|до\s*(\d+[\d\s]*)\s*([A-Z]{3})?|от\s*(\d+[\d\s]*)\s*([A-Z]{3})?|(\d+[\d\s]*)\s*([A-Z]{3})?'
    not_specified_pattern = r'з/п не указана'
    currency_pattern = r'([A-Z]{3})$'
    
    for idx, value in enumerate(result_df[salary_column]):
        if pd.isna(value):
            continue
            
        value_str = str(value).strip()
        
        # Проверяем на "з/п не указана"
        if re.search(not_specified_pattern, value_str, re.IGNORECASE):
            result_df.at[idx, f'{new_columns_prefix}salary_from'] = np.nan
            result_df.at[idx, f'{new_columns_prefix}salary_to'] = np.nan
            result_df.at[idx, f'{new_columns_prefix}currency'] = np.nan
            continue
        
        # Ищем валюту в конце строки
        currency_match = re.search(currency_pattern, value_str)
        currency = currency_match.group(1) if currency_match else np.nan
        
        # Парсим зарплату
        salary_match = re.search(salary_pattern, value_str, re.IGNORECASE)
        
        if salary_match:
            groups = salary_match.groups()
            
            # Вариант: "от X до Y CUR"
            if groups[0] and groups[1]:
                salary_from = groups[0].replace(' ', '')
                salary_to = groups[1].replace(' ', '')
                currency_val = groups[2] if groups[2] else currency
            
            # Вариант: "до X CUR"
            elif groups[3]:
                salary_from = np.nan
                salary_to = groups[3].replace(' ', '')
                currency_val = groups[4] if groups[4] else currency
            
            # Вариант: "от X CUR"
            elif groups[5]:
                salary_from = groups[5].replace(' ', '')
                salary_to = np.nan
                currency_val = groups[6] if groups[6] else currency
            
            # Вариант: "X CUR"
            elif groups[7]:
                salary_from = groups[7].replace(' ', '')
                salary_to = np.nan
                currency_val = groups[8] if groups[8] else currency
            
            else:
                salary_from = np.nan
                salary_to = np.nan
                currency_val = np.nan
            
            # Записываем значения
            result_df.at[idx, f'{new_columns_prefix}salary_from'] = float(salary_from) if salary_from and salary_from != 'nan' else np.nan
            result_df.at[idx, f'{new_columns_prefix}salary_to'] = float(salary_to) if salary_to and salary_to != 'nan' else np.nan
            result_df.at[idx, f'{new_columns_prefix}currency'] = currency_val if currency_val and currency_val != 'nan' else np.nan
    
    return result_df

# %%
data_set_1 = split_salary_column(data_set_1, 'salary')
# Out:
# /var/folders/lk/c663_dk55yb69cnx4blm8wqr0000gn/T/ipykernel_92192/689102006.py:82: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'RUR' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   result_df.at[idx, f'{new_columns_prefix}currency'] = currency_val if currency_val and currency_val != 'nan' else np.nan

# %%
def split_experience_column(df, experience_column, new_columns_prefix=''):
    """
    Разделяет столбец с опытом работы на три отдельных столбца.
    
    Parameters:
    df (DataFrame): Исходный датафрейм
    experience_column (str): Название столбца с опытом работы
    new_columns_prefix (str): Префикс для новых столбцов
    
    Returns:
    DataFrame: Дадафрейм с добавленными столбцами experience_from, experience_to, no_experience
    """
    
    # Создаем копию датафрейма
    result_df = df.copy()
    
    # Создаем новые столбцы
    result_df[f'{new_columns_prefix}experience_from'] = np.nan
    result_df[f'{new_columns_prefix}experience_to'] = np.nan
    result_df[f'{new_columns_prefix}no_experience'] = False
    
    # Регулярные выражения для парсинга
    no_experience_pattern = r'(нет опыта|без опыта|без опыта работы|опыт не требуется|не требуется опыт)'
    
    experience_pattern = r'''
        от\s+(\d+)\s*(?:года|лет|год)\s+до\s+(\d+)\s*(?:года|лет|год)|  # от X года до Y года
        до\s+(\d+)\s*(?:года|лет|год)|                                  # до X года
        от\s+(\d+)\s*(?:года|лет|год)|                                  # от X года
        более\s+(\d+)\s*(?:года|лет|год)|                               # более X года
        (\d+)\s*(?:года|лет|год)                                        # X года
    '''
    
    for idx, value in enumerate(result_df[experience_column]):
        if pd.isna(value):
            continue
            
        value_str = str(value).strip().lower()
        
        # Проверяем на "нет опыта"
        if re.search(no_experience_pattern, value_str, re.IGNORECASE):
            result_df.at[idx, f'{new_columns_prefix}no_experience'] = True
            result_df.at[idx, f'{new_columns_prefix}experience_from'] = np.nan
            result_df.at[idx, f'{new_columns_prefix}experience_to'] = np.nan
            continue
        
        # Парсим опыт работы
        experience_match = re.search(experience_pattern, value_str, re.IGNORECASE | re.VERBOSE)
        
        if experience_match:
            groups = experience_match.groups()
            
            # Вариант: "от X года до Y года"
            if groups[0] and groups[1]:
                experience_from = groups[0]
                experience_to = groups[1]
            
            # Вариант: "до X года"
            elif groups[2]:
                experience_from = np.nan
                experience_to = groups[2]
            
            # Вариант: "от X года"
            elif groups[3]:
                experience_from = groups[3]
                experience_to = np.nan
            
            # Вариант: "более X года"
            elif groups[4]:
                experience_from = groups[4]
                experience_to = np.nan
            
            # Вариант: "X года"
            elif groups[5]:
                experience_from = groups[5]
                experience_to = np.nan
            
            else:
                experience_from = np.nan
                experience_to = np.nan
            
            # Записываем значения
            result_df.at[idx, f'{new_columns_prefix}experience_from'] = float(experience_from) if experience_from and experience_from != 'nan' else np.nan
            result_df.at[idx, f'{new_columns_prefix}experience_to'] = float(experience_to) if experience_to and experience_to != 'nan' else np.nan
            
            # Устанавливаем no_experience = False если есть хотя бы одно значение
            if pd.notna(result_df.at[idx, f'{new_columns_prefix}experience_from']) or \
               pd.notna(result_df.at[idx, f'{new_columns_prefix}experience_to']):
                result_df.at[idx, f'{new_columns_prefix}no_experience'] = False
    
    return result_df

# Дополнительная функция для проверки результатов
def check_experience_splitting(df, original_column):
    """Проверяет корректность разделения опыта работы"""
    print("=== ПРОВЕРКА РАЗДЕЛЕНИЯ ОПЫТА РАБОТЫ ===")
    print(f"Всего строк: {len(df)}")
    print(f"Без опыта: {df['no_experience'].sum()}")
    print(f"С опытом: {len(df) - df['no_experience'].sum()}")
    
    print("\nПримеры данных:")
    for i in range(min(10, len(df))):
        print(f"{i}: '{df[original_column].iloc[i]}' -> "
              f"from: {df['experience_from'].iloc[i]}, "
              f"to: {df['experience_to'].iloc[i]}, "
              f"no_exp: {df['no_experience'].iloc[i]}")

# %%
data_set_1 = split_experience_column(data_set_1, 'experience')

# %%
def split_by_comma_advanced(result_df, source_column, concrete_column='job_type_concrete', schedule_column='schedule', to_lowercase=True, remove_extra_spaces=True):
    """
    Расширенная версия с опциями предобработки.
    
    Parameters:
    to_lowercase (bool): Приводить ли к нижнему регистру
    remove_extra_spaces (bool): Убирать ли лишние пробелы
    """
    
    result_df[concrete_column] = np.nan
    result_df[schedule_column] = np.nan
    
    for idx, value in enumerate(result_df[source_column]):
        if pd.isna(value):
            continue
            
        value_str = str(value).strip()
        
        # Приведение к нижнему регистру (если включено)
        if to_lowercase:
            value_str = value_str.lower()
        
        # Удаление лишних пробелов (если включено)
        if remove_extra_spaces:
            value_str = ' '.join(value_str.split())
        
        if ',' in value_str:
            parts = value_str.split(',', 1)
            concrete_part = parts[0].strip()
            schedule_part = parts[1].strip()
            
            result_df.at[idx, concrete_column] = concrete_part if concrete_part else np.nan
            result_df.at[idx, schedule_column] = schedule_part if schedule_part else np.nan
        else:
            result_df.at[idx, concrete_column] = value_str if value_str else np.nan
            result_df.at[idx, schedule_column] = np.nan
    
    return result_df

# %%
data_set_1 = split_by_comma_advanced(data_set_1, 'job_type')
# Out:
# /var/folders/lk/c663_dk55yb69cnx4blm8wqr0000gn/T/ipykernel_92192/4133146593.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'полная занятость' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   result_df.at[idx, concrete_column] = concrete_part if concrete_part else np.nan
# /var/folders/lk/c663_dk55yb69cnx4blm8wqr0000gn/T/ipykernel_92192/4133146593.py:33: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'полный день' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   result_df.at[idx, schedule_column] = schedule_part if schedule_part else np.nan

# %%
columns_to_drop = ['salary', 'experience', 'job_type']
data_set_1 = data_set_1.drop(columns=columns_to_drop)

# %%
data_set_1
# Out:
#              №        id                                            title  \
# 0            1  78577559                                  Главный механик
# 1            2  78693069                                 HTML-верстальщик
# 2            3  78945452  Тренер (направление профессионального обучения)
# 3            4  79352008                          Старший механик на КСПГ
# 4            5  79406472                           System Analyst Trainee
# ...        ...       ...                                              ...
# 561984  561995  81056636                      Аналитик (бизнес/системный)
# 561985  561996  81036428                    Разнорабочий/транспортировщик
# 561986  561997  81962116                          Рабочий на производство
# 561987  561998  81487376                              Менеджер по туризму
# 561988  561999  80897895                  Токарь на оборонное предприятие
#
#                                               description  \
# 0       Вакансия компании:   ООО ПК Предприятие "ПИК" ...
# 1       В креативное агентство на полный рабочий день ...
# 2         Наши предложения:        самостоятельность в...
# 3         Обязанности:        _Обеспечение технически ...
# 4       IT-компания Aston - компания по разработке про...
# ...                                                   ...
# 561984  Мы – аккредитованная IT-компания   «Формат код...
# 561985    Обязанности:        Работа транспортировщико...
# 561986    На крупные федеральные производства РФ для р...
# 561987  В связи с открытием нового офиса в г. Мытищи, ...
# 561988  Работа на крупном оборонном заводе Курганской ...
#
#                                                key_skills  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4       UML,SQL,Scrum,Retail,Базы данных,Kanban,Waterf...
# ...                                                   ...
# 561984                                                NaN
# 561985                                                NaN
# 561986  Желание работать и зарабатывать,Быстрообучаемы...
# 561987                                                NaN
# 561988                                                NaN
#
#                      company     location date_of_post   type  salary_from  \
# 0                    JCat.ru  Владивосток   27.03.2023  close     160000.0
# 1             Чугунова Ирина          NaN   29.03.2023  close          NaN
# 2                Перекрёсток          NaN   18.04.2023  close          NaN
# 3       Газпром гелий сервис          NaN   17.04.2023  close          NaN
# 4                      Aston          NaN   17.04.2023  close          NaN
# ...                      ...          ...          ...    ...          ...
# 561984           Формат кода          NaN   06.06.2023   open          NaN
# 561985      Консалтинг Групп          NaN   09.06.2023   open     110000.0
# 561986              ПРОКАДРЫ          NaN   15.06.2023   open      80000.0
# 561987              Скайлайн          NaN   03.06.2023   open      60000.0
# 561988            ГК ПАРТНЁР          NaN   16.06.2023   open     120000.0
#
#         salary_to currency  experience_from  experience_to  no_experience  \
# 0        160000.0      RUR              6.0            NaN          False
# 1             NaN      NaN              1.0            3.0          False
# 2             NaN      NaN              1.0            3.0          False
# 3             NaN      NaN              6.0            NaN          False
# 4             NaN      NaN              NaN            NaN           True
# ...           ...      ...              ...            ...            ...
# 561984        NaN      NaN              1.0            3.0          False
# 561985   130000.0      RUR              NaN            NaN           True
# 561986    85000.0      RUR              NaN            NaN           True
# 561987        NaN      RUR              1.0            3.0          False
# 561988        NaN      RUR              1.0            3.0          False
#
#        job_type_concrete        schedule
# 0       полная занятость     полный день
# 1       полная занятость     полный день
# 2       полная занятость     полный день
# 3       полная занятость     полный день
# 4             стажировка     полный день
# ...                  ...             ...
# 561984  полная занятость     полный день
# 561985  полная занятость  вахтовый метод
# 561986  полная занятость  вахтовый метод
# 561987  полная занятость  сменный график
# 561988  полная занятость  вахтовый метод
#
# [561989 rows x 17 columns]

# %%
data_set_2 = pd.read_csv('/Users/natalialogvinova/Desktop/DS diploma/DS-17 diploma/Data Analyst Vacancies.csv', sep = ',')
print(data_set_2.shape)
data_set_2.head(5)
# Out:
# (1000, 36)
#          id  premium                               name department  has_test  \
# 0  86571284    False  Data Scientist (стажер), удаленно        NaN     False
# 1  87273897    False                       Data Analyst        NaN     False
# 2  87271975    False                  Political analyst        NaN     False
# 3  86195321    False              Junior Data Scientist        NaN     False
# 4  87265216    False                              Юрист        NaN      True
#
#    response_letter_required  \
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
#
#                                                 area  \
# 0  {'id': '1', 'name': 'Москва', 'url': 'https://...
# 1  {'id': '1', 'name': 'Москва', 'url': 'https://...
# 2  {'id': '1', 'name': 'Москва', 'url': 'https://...
# 3  {'id': '1', 'name': 'Москва', 'url': 'https://...
# 4  {'id': '1', 'name': 'Москва', 'url': 'https://...
#
#                                               salary  \
# 0  {'from': None, 'to': 15000, 'currency': 'RUR',...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                        type address  ...  \
# 0        {'id': 'open', 'name': 'Открытая'}     NaN  ...
# 1        {'id': 'open', 'name': 'Открытая'}     NaN  ...
# 2  {'id': 'anonymous', 'name': 'Анонимная'}     NaN  ...
# 3        {'id': 'open', 'name': 'Открытая'}     NaN  ...
# 4        {'id': 'open', 'name': 'Открытая'}     NaN  ...
#
#                               working_time_intervals  \
# 0  [{'id': 'from_four_to_six_hours_in_a_day', 'na...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                                   working_time_modes accept_temporary  \
# 0  [{'id': 'start_after_sixteen', 'name': 'Можно ...            False
# 1                                                 []            False
# 2                                                 []            False
# 3                                                 []            False
# 4                                                 []            False
#
#                                   professional_roles  \
# 0  [{'id': '96', 'name': 'Программист, разработчи...
# 1  [{'id': '156', 'name': 'BI-аналитик, аналитик ...
# 2                   [{'id': '40', 'name': 'Другое'}]
# 3          [{'id': '165', 'name': 'Дата-сайентист'}]
# 4                   [{'id': '146', 'name': 'Юрист'}]
#
#    accept_incomplete_resumes  \
# 0                      False
# 1                      False
# 2                      False
# 3                      False
# 4                      False
#
#                                           experience  \
# 0        {'id': 'noExperience', 'name': 'Нет опыта'}
# 1    {'id': 'between3And6', 'name': 'От 3 до 6 лет'}
# 2         {'id': 'moreThan6', 'name': 'Более 6 лет'}
# 3  {'id': 'between1And3', 'name': 'От 1 года до 3...
# 4  {'id': 'between1And3', 'name': 'От 1 года до 3...
#
#                                    employment adv_response_url is_adv_vacancy  \
# 0   {'id': 'probation', 'name': 'Стажировка'}              NaN          False
# 1  {'id': 'full', 'name': 'Полная занятость'}              NaN          False
# 2  {'id': 'full', 'name': 'Полная занятость'}              NaN          False
# 3  {'id': 'full', 'name': 'Полная занятость'}              NaN          False
# 4  {'id': 'full', 'name': 'Полная занятость'}              NaN          False
#
#                              branding
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3  {'type': 'MAKEUP', 'tariff': None}
# 4                                 NaN
#
# [5 rows x 36 columns]

# %%
import ast

def split_salary_column_dict_string(df, salary_column):
    """
    Разделяет столбец с зарплатой в формате строки-словаря на три отдельных столбца.
    
    Parameters:
    df (DataFrame): Исходный датафрейм
    salary_column (str): Название столбца с зарплатой в формате строки-словаря
    
    Returns:
    DataFrame: Дадафрейм с добавленными столбцами salary_from, salary_to, currency
    """
    
    # Создаем копию датафрейма
    result_df = df.copy()
    
    # Создаем новые столбцы
    result_df['salary_from'] = np.nan
    result_df['salary_to'] = np.nan
    result_df['currency'] = np.nan
    
    for idx, value in enumerate(result_df[salary_column]):
        # Пропускаем NaN значения
        if pd.isna(value):
            continue
            
        # Пропускаем пустые строки
        if isinstance(value, str) and value.strip() == '':
            continue
            
        # Пробуем распарсить строку как словарь Python
        try:
            # Используем ast.literal_eval для безопасного парсинга
            salary_dict = ast.literal_eval(value)
            
            # Проверяем, что получили словарь
            if isinstance(salary_dict, dict):
                # Извлекаем значения, преобразуя None в NaN
                salary_from = salary_dict.get('from')
                salary_to = salary_dict.get('to')
                currency = salary_dict.get('currency')
                
                # Записываем значения
                result_df.at[idx, 'salary_from'] = float(salary_from) if salary_from is not None else np.nan
                result_df.at[idx, 'salary_to'] = float(salary_to) if salary_to is not None else np.nan
                result_df.at[idx, 'currency'] = currency if currency is not None else np.nan
                
        except (ValueError, SyntaxError, TypeError) as e:
            # Если не удалось распарсить, оставляем NaN
            print(f"Ошибка парсинга строки {idx}: '{value}' - {e}")
            continue
    
    return result_df

# %%
data_set_2 = split_salary_column_dict_string(data_set_2, 'salary')
# Out:
# /var/folders/lk/c663_dk55yb69cnx4blm8wqr0000gn/T/ipykernel_92192/477433147.py:47: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'RUR' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   result_df.at[idx, 'currency'] = currency if currency is not None else np.nan

# %%
def split_experience_column_simple(df, experience_column):
    """
    Упрощенная версия, которая извлекает только поле name и парсит его.
    """
    
    result_df = df.copy()
    result_df['experience_from'] = np.nan
    result_df['experience_to'] = np.nan
    result_df['no_experience'] = False
    
    for idx, value in enumerate(result_df[experience_column]):
        if pd.isna(value):
            continue
            
        value_str = str(value).strip()
        if not value_str or value_str == 'nan':
            continue
            
        # Извлекаем текст из поля name
        name_text = None
        
        # Пробуем извлечь поле name разными способами
        try:
            # Способ 1: через ast.literal_eval
            exp_dict = ast.literal_eval(value_str)
            if isinstance(exp_dict, dict) and 'name' in exp_dict:
                name_text = str(exp_dict['name']).strip().lower()
        except:
            # Способ 2: через поиск в строке
            name_match = re.search(r"'name'\s*:\s*'([^']*)'", value_str)
            if name_match:
                name_text = name_match.group(1).strip().lower()
        
        if not name_text:
            continue
        
        # Парсим текст опыта
        # 1. Проверяем "нет опыта"
        if any(phrase in name_text for phrase in ['нет опыта', 'без опыта', 'опыт не требуется']):
            result_df.at[idx, 'no_experience'] = True
            result_df.at[idx, 'experience_from'] = 0
            result_df.at[idx, 'experience_to'] = 0
            continue
        
        # 2. Парсим числовые значения
        # "от X до Y"
        range_match = re.search(r'от\s*(\d+)\s*до\s*(\d+)', name_text)
        if range_match:
            result_df.at[idx, 'experience_from'] = float(range_match.group(1))
            result_df.at[idx, 'experience_to'] = float(range_match.group(2))
            continue
        
        # "от X"
        from_match = re.search(r'от\s*(\d+)', name_text)
        if from_match:
            result_df.at[idx, 'experience_from'] = float(from_match.group(1))
            continue
        
        # "до X"
        to_match = re.search(r'до\s*(\d+)', name_text)
        if to_match:
            result_df.at[idx, 'experience_to'] = float(to_match.group(1))
            continue
        
        # "более X"
        more_match = re.search(r'более\s*(\d+)', name_text)
        if more_match:
            result_df.at[idx, 'experience_from'] = float(more_match.group(1))
            continue
        
        # "X лет/год/года"
        simple_match = re.search(r'(\d+)\s*(?:лет|год|года)', name_text)
        if simple_match:
            result_df.at[idx, 'experience_from'] = float(simple_match.group(1))
    
    return result_df

# %%
data_set_2 = split_experience_column_simple(data_set_2, 'experience')

# %%
def extract_job_type_simple(df, source_column, target_column):
    
    result_df = df.copy()
    result_df[target_column] = np.nan
    
    for idx, value in enumerate(result_df[source_column]):
        if pd.isna(value):
            continue
            
        value_str = str(value).strip()
        if not value_str or value_str == 'nan':
            continue
        
        # Пробуем извлечь поле name разными способами
        try:
            # Способ 1: через ast.literal_eval
            job_dict = ast.literal_eval(value_str)
            if isinstance(job_dict, dict) and 'name' in job_dict:
                result_df.at[idx, target_column] = str(job_dict['name']).strip()
        except:
            # Способ 2: через регулярное выражение (если не получается распарсить как словарь)
            try:
                import re
                name_match = re.search(r"'name'\s*:\s*'([^']*)'", value_str)
                if name_match:
                    result_df.at[idx, target_column] = name_match.group(1).strip()
            except:
                continue
    
    return result_df

# %%
data_set_2 = extract_job_type_simple(data_set_2, 'employment', 'job_type_concrete')
# Out:
# /var/folders/lk/c663_dk55yb69cnx4blm8wqr0000gn/T/ipykernel_92192/1209430768.py:19: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Стажировка' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   result_df.at[idx, target_column] = str(job_dict['name']).strip()

# %%
data_set_2['location'] = 'Москва'

# %%
data_set_2['type'] = 'open'

# %%
data_set_2 = extract_job_type_simple(data_set_2, 'department', 'company')
# Out:
# /var/folders/lk/c663_dk55yb69cnx4blm8wqr0000gn/T/ipykernel_92192/1209430768.py:19: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'ВкусВилл. Офис' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   result_df.at[idx, target_column] = str(job_dict['name']).strip()

# %%
def quick_extract_company(df, source_column, target_column='company'):
    """
    Быстрая версия для извлечения названия компании.
    """
    
    def extract_company_value(value):
        if pd.isna(value):
            return np.nan
            
        try:
            value_str = str(value)
            if not value_str or value_str == 'nan':
                return np.nan
                
            # Пробуем распарсить как словарь
            if value_str.startswith('{'):
                company_dict = ast.literal_eval(value_str)
                if isinstance(company_dict, dict):
                    return company_dict.get('name', np.nan)
            return np.nan
        except:
            return np.nan
    
    result_df = df.copy()
    result_df[target_column] = result_df[source_column].apply(extract_company_value)
    
    return result_df

# %%
data_set_2 = quick_extract_company(data_set_2, 'employer')

# %%
data_set_2
# Out:
#            id  premium                               name  \
# 0    86571284    False  Data Scientist (стажер), удаленно
# 1    87273897    False                       Data Analyst
# 2    87271975    False                  Political analyst
# 3    86195321    False              Junior Data Scientist
# 4    87265216    False                              Юрист
# ..        ...      ...                                ...
# 995  86658658    False           Mobile Marketing Manager
# 996  86078517    False          Senior Data Scientist NLP
# 997  86817040    False           Team Lead Data Scientist
# 998  86755769    False            Архитектор данных (B2C)
# 999  84826918    False          Категорийный менеджер СТМ
#
#                                             department  has_test  \
# 0                                                  NaN     False
# 1                                                  NaN     False
# 2                                                  NaN     False
# 3                                                  NaN     False
# 4                                                  NaN      True
# ..                                                 ...       ...
# 995                                                NaN     False
# 996  {'id': '3529-3529-prof', 'name': 'Сбер для экс...     False
# 997  {'id': '3529-3529-prof', 'name': 'Сбер для экс...     False
# 998         {'id': '3529-3529-it', 'name': 'Сбер. IT'}     False
# 999                                                NaN     False
#
#      response_letter_required  \
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
# ..                        ...
# 995                     False
# 996                     False
# 997                     False
# 998                     False
# 999                     False
#
#                                                   area  \
# 0    {'id': '1', 'name': 'Москва', 'url': 'https://...
# 1    {'id': '1', 'name': 'Москва', 'url': 'https://...
# 2    {'id': '1', 'name': 'Москва', 'url': 'https://...
# 3    {'id': '1', 'name': 'Москва', 'url': 'https://...
# 4    {'id': '1', 'name': 'Москва', 'url': 'https://...
# ..                                                 ...
# 995  {'id': '1', 'name': 'Москва', 'url': 'https://...
# 996  {'id': '1', 'name': 'Москва', 'url': 'https://...
# 997  {'id': '1', 'name': 'Москва', 'url': 'https://...
# 998  {'id': '1', 'name': 'Москва', 'url': 'https://...
# 999  {'id': '1', 'name': 'Москва', 'url': 'https://...
#
#                                                 salary  type  \
# 0    {'from': None, 'to': 15000, 'currency': 'RUR',...  open
# 1                                                  NaN  open
# 2                                                  NaN  open
# 3                                                  NaN  open
# 4                                                  NaN  open
# ..                                                 ...   ...
# 995                                                NaN  open
# 996                                                NaN  open
# 997                                                NaN  open
# 998                                                NaN  open
# 999  {'from': 200000, 'to': 500000, 'currency': 'RU...  open
#
#                                                address  ...  \
# 0                                                  NaN  ...
# 1                                                  NaN  ...
# 2                                                  NaN  ...
# 3                                                  NaN  ...
# 4                                                  NaN  ...
# ..                                                 ...  ...
# 995  {'city': 'Москва', 'street': 'Новодмитровская ...  ...
# 996                                                NaN  ...
# 997                                                NaN  ...
# 998  {'city': 'Москва', 'street': 'Кутузовский прос...  ...
# 999  {'city': 'Москва', 'street': 'Воронцовская ули...  ...
#
#                                branding  salary_from salary_to currency  \
# 0                                   NaN          NaN   15000.0      RUR
# 1                                   NaN          NaN       NaN      NaN
# 2                                   NaN          NaN       NaN      NaN
# 3    {'type': 'MAKEUP', 'tariff': None}          NaN       NaN      NaN
# 4                                   NaN          NaN       NaN      NaN
# ..                                  ...          ...       ...      ...
# 995                                 NaN          NaN       NaN      NaN
# 996  {'type': 'MAKEUP', 'tariff': None}          NaN       NaN      NaN
# 997  {'type': 'MAKEUP', 'tariff': None}          NaN       NaN      NaN
# 998  {'type': 'MAKEUP', 'tariff': None}          NaN       NaN      NaN
# 999  {'type': 'MAKEUP', 'tariff': None}     200000.0  500000.0      RUR
#
#      experience_from experience_to no_experience job_type_concrete location  \
# 0                0.0           0.0          True        Стажировка   Москва
# 1                3.0           6.0         False  Полная занятость   Москва
# 2                6.0           NaN         False  Полная занятость   Москва
# 3                1.0           NaN         False  Полная занятость   Москва
# 4                1.0           NaN         False  Полная занятость   Москва
# ..               ...           ...           ...               ...      ...
# 995              1.0           NaN         False  Полная занятость   Москва
# 996              3.0           6.0         False  Полная занятость   Москва
# 997              6.0           NaN         False  Полная занятость   Москва
# 998              3.0           6.0         False  Полная занятость   Москва
# 999              1.0           NaN         False  Полная занятость   Москва
#
#                                  company
# 0               Дунаев Михаил Алексеевич
# 1                           Aviasales.ru
# 2                      Political Analyst
# 3    Бюро кредитных историй Скоринг Бюро
# 4                           Skillfactory
# ..                                   ...
# 995                             Адвентум
# 996                                 СБЕР
# 997                                 СБЕР
# 998                                 СБЕР
# 999                    ВсеИнструменты.ру
#
# [1000 rows x 45 columns]

# %%
rename_dict = {
    'name': 'title',
    'published_at': 'date_of_post', 
    'snippet': 'description'
}

# %%
data_set_2 = data_set_2.rename(columns=rename_dict)

# %%
def concat_preserve_first_structure(df1, df2):
    """
    Соединяет два датафрейма снизу, сохраняя структуру столбцов из первого датафрейма.
    """
    # Сохраняем порядок и набор столбцов из первого датафрейма
    columns_order = df1.columns.tolist()
    
    # Добавляем недостающие столбцы во второй датафрейм с значениями NaN
    for col in columns_order:
        if col not in df2.columns:
            df2[col] = np.nan
    
    # Приводим второй датафрейм к тому же порядку столбцов
    df2 = df2[columns_order]
    
    # Объединяем датафреймы
    result_df = pd.concat([df1, df2], axis=0, ignore_index=True)
    
    return result_df

# %%
data_set_12 = concat_preserve_first_structure(data_set_1, data_set_2)

# %%
data_set_12
# Out:
#           №        id                                            title  \
# 0       1.0  78577559                                  Главный механик
# 1       2.0  78693069                                 HTML-верстальщик
# 2       3.0  78945452  Тренер (направление профессионального обучения)
# 3       4.0  79352008                          Старший механик на КСПГ
# 4       5.0  79406472                           System Analyst Trainee
# ...     ...       ...                                              ...
# 562984  NaN  86658658                         Mobile Marketing Manager
# 562985  NaN  86078517                        Senior Data Scientist NLP
# 562986  NaN  86817040                         Team Lead Data Scientist
# 562987  NaN  86755769                          Архитектор данных (B2C)
# 562988  NaN  84826918                        Категорийный менеджер СТМ
#
#                                               description  \
# 0       Вакансия компании:   ООО ПК Предприятие "ПИК" ...
# 1       В креативное агентство на полный рабочий день ...
# 2         Наши предложения:        самостоятельность в...
# 3         Обязанности:        _Обеспечение технически ...
# 4       IT-компания Aston - компания по разработке про...
# ...                                                   ...
# 562984  {'requirement': 'Умеете анализировать большой ...
# 562985  {'requirement': 'Имплементация и обучение новы...
# 562986  {'requirement': 'Отличное понимание классическ...
# 562987  {'requirement': 'Высшее техническое образовани...
# 562988  {'requirement': 'Переговорные навыки (есть бол...
#
#                                                key_skills  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4       UML,SQL,Scrum,Retail,Базы данных,Kanban,Waterf...
# ...                                                   ...
# 562984                                                NaN
# 562985                                                NaN
# 562986                                                NaN
# 562987                                                NaN
# 562988                                                NaN
#
#                      company     location              date_of_post   type  \
# 0                    JCat.ru  Владивосток                27.03.2023  close
# 1             Чугунова Ирина          NaN                29.03.2023  close
# 2                Перекрёсток          NaN                18.04.2023  close
# 3       Газпром гелий сервис          NaN                17.04.2023  close
# 4                      Aston          NaN                17.04.2023  close
# ...                      ...          ...                       ...    ...
# 562984              Адвентум       Москва  2023-09-13T11:46:23+0300   open
# 562985                  СБЕР       Москва  2023-08-31T18:46:17+0300   open
# 562986                  СБЕР       Москва  2023-09-17T13:48:31+0300   open
# 562987                  СБЕР       Москва  2023-09-15T08:59:09+0300   open
# 562988     ВсеИнструменты.ру       Москва  2023-09-25T14:10:13+0300   open
#
#         salary_from  salary_to currency  experience_from  experience_to  \
# 0          160000.0   160000.0      RUR              6.0            NaN
# 1               NaN        NaN      NaN              1.0            3.0
# 2               NaN        NaN      NaN              1.0            3.0
# 3               NaN        NaN      NaN              6.0            NaN
# 4               NaN        NaN      NaN              NaN            NaN
# ...             ...        ...      ...              ...            ...
# 562984          NaN        NaN      NaN              1.0            NaN
# 562985          NaN        NaN      NaN              3.0            6.0
# 562986          NaN        NaN      NaN              6.0            NaN
# 562987          NaN        NaN      NaN              3.0            6.0
# 562988     200000.0   500000.0      RUR              1.0            NaN
#
#         no_experience job_type_concrete     schedule
# 0               False  полная занятость  полный день
# 1               False  полная занятость  полный день
# 2               False  полная занятость  полный день
# 3               False  полная занятость  полный день
# 4                True        стажировка  полный день
# ...               ...               ...          ...
# 562984          False  Полная занятость          NaN
# 562985          False  Полная занятость          NaN
# 562986          False  Полная занятость          NaN
# 562987          False  Полная занятость          NaN
# 562988          False  Полная занятость          NaN
#
# [562989 rows x 17 columns]

# %%
data_set_3 = pd.read_csv('/Users/natalialogvinova/Desktop/DS diploma/DS-17 diploma/IT_vacancies.csv', sep = ',')
print(data_set_3.shape)
data_set_3.head(5)
# Out:
# (68770, 54)
#          id  area_id        area_name  \
# 0  85146733        2  Санкт-Петербург
# 1  87391606        1           Москва
# 2  85896506       79          Саратов
# 3  86876446       72            Пермь
# 4  84560508       76   Ростов-на-Дону
#
#                                                 name test_required  salary_to  \
# 0  Тестировщик / QA Engineer (Junior / Middle / S...           NaN        NaN
# 1        Ведущий Системный Аналитик Kleiber.Graphics           NaN   250000.0
# 2                                    Бизнес-аналитик           NaN        NaN
# 3  Менеджер проектов/Аккаунт-менеджер (IT сфера) ...           NaN        NaN
# 4  Специалист службы поддержки (удаленно), Ростов...           NaN        NaN
#
#    salary_from salary_gross salary_currency  address_lat  ...  \
# 0          NaN          NaN             NaN    59.984924  ...
# 1     230000.0        False             RUR          NaN  ...
# 2          NaN          NaN             NaN          NaN  ...
# 3          NaN          NaN             NaN    58.004460  ...
# 4      35000.0         True             RUR          NaN  ...
#
#    accept_temporary accept_handicapped professional_roles_id  \
# 0             False               True                   124
# 1             False              False                   148
# 2             False              False                    10
# 3             False              False                   107
# 4             False              False                   121
#
#             professional_roles_name working_time_modes driver_license_types  \
# 0                       Тестировщик                NaN                  NaN
# 1                Системный аналитик                NaN                  NaN
# 2                          Аналитик                NaN                  NaN
# 3             Руководитель проектов                NaN                  NaN
# 4  Специалист технической поддержки                NaN                  NaN
#
#    working_time_intervals  quick_responses_allowed response_letter_required  \
# 0                     NaN                    False                    False
# 1                     NaN                    False                    False
# 2                     NaN                    False                    False
# 3                     NaN                    False                    False
# 4                     NaN                    False                    False
#
#   accept_incomplete_resumes
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
#
# [5 rows x 54 columns]

# %%
data_set_3 = split_experience_column(data_set_3, 'experience')

# %%
data_set_3
# Out:
#              id  area_id        area_name  \
# 0      85146733        2  Санкт-Петербург
# 1      87391606        1           Москва
# 2      85896506       79          Саратов
# 3      86876446       72            Пермь
# 4      84560508       76   Ростов-на-Дону
# ...         ...      ...              ...
# 68765  88274679        1           Москва
# 68766  88285292        1           Москва
# 68767  84616188     1204           Бердск
# 68768  88277660     1928          Узловая
# 68769  85378686       53        Краснодар
#
#                                                     name test_required  \
# 0      Тестировщик / QA Engineer (Junior / Middle / S...           NaN
# 1            Ведущий Системный Аналитик Kleiber.Graphics           NaN
# 2                                        Бизнес-аналитик           NaN
# 3      Менеджер проектов/Аккаунт-менеджер (IT сфера) ...           NaN
# 4      Специалист службы поддержки (удаленно), Ростов...           NaN
# ...                                                  ...           ...
# 68765  Заместитель технического директора по электрот...           NaN
# 68766  Инженер / Presale по серверному оборудованию и...           NaN
# 68767                                     Программист 1C           NaN
# 68768          Инженер-программист (Промет СЭЗ, Узловая)           NaN
# 68769                             Специалист 1С (стажер)           NaN
#
#        salary_to  salary_from salary_gross salary_currency  address_lat  ...  \
# 0            NaN          NaN          NaN             NaN    59.984924  ...
# 1       250000.0     230000.0        False             RUR          NaN  ...
# 2            NaN          NaN          NaN             NaN          NaN  ...
# 3            NaN          NaN          NaN             NaN    58.004460  ...
# 4            NaN      35000.0         True             RUR          NaN  ...
# ...          ...          ...          ...             ...          ...  ...
# 68765        NaN          NaN          NaN             NaN          NaN  ...
# 68766   300000.0     150000.0        False             RUR    55.714653  ...
# 68767        NaN      80000.0        False             RUR          NaN  ...
# 68768        NaN     130000.0         True             RUR          NaN  ...
# 68769    60000.0      35000.0        False             RUR    45.036330  ...
#
#                 professional_roles_name working_time_modes  \
# 0                           Тестировщик                NaN
# 1                    Системный аналитик                NaN
# 2                              Аналитик                NaN
# 3                 Руководитель проектов                NaN
# 4      Специалист технической поддержки                NaN
# ...                                 ...                ...
# 68765        Технический директор (CTO)                NaN
# 68766  Специалист технической поддержки                NaN
# 68767          Программист, разработчик                NaN
# 68768          Программист, разработчик                NaN
# 68769          Программист, разработчик                NaN
#
#       driver_license_types  working_time_intervals quick_responses_allowed  \
# 0                      NaN                     NaN                   False
# 1                      NaN                     NaN                   False
# 2                      NaN                     NaN                   False
# 3                      NaN                     NaN                   False
# 4                      NaN                     NaN                   False
# ...                    ...                     ...                     ...
# 68765                  NaN                     NaN                   False
# 68766                  NaN                     NaN                   False
# 68767                  NaN                     NaN                   False
# 68768                  NaN                     NaN                   False
# 68769                  NaN                     NaN                   False
#
#       response_letter_required  accept_incomplete_resumes  experience_from  \
# 0                        False                      False              1.0
# 1                        False                      False              NaN
# 2                        False                      False              NaN
# 3                        False                      False              1.0
# 4                        False                      False              NaN
# ...                        ...                        ...              ...
# 68765                    False                      False              6.0
# 68766                    False                      False              1.0
# 68767                    False                      False              NaN
# 68768                    False                      False              NaN
# 68769                    False                      False              NaN
#
#       experience_to no_experience
# 0               3.0         False
# 1               6.0         False
# 2               6.0         False
# 3               3.0         False
# 4               NaN          True
# ...             ...           ...
# 68765           NaN         False
# 68766           3.0         False
# 68767           6.0         False
# 68768           6.0         False
# 68769           NaN          True
#
# [68770 rows x 57 columns]

# %%
rename_dict = {
    'name': 'title',
    'area_name': 'location', 
    'employer_name': 'company',
    'published_at': 'date_of_post',
    'employment' : 'job_type_concrete'
}

# %%
data_set_3
# Out:
#              id  area_id        area_name  \
# 0      85146733        2  Санкт-Петербург
# 1      87391606        1           Москва
# 2      85896506       79          Саратов
# 3      86876446       72            Пермь
# 4      84560508       76   Ростов-на-Дону
# ...         ...      ...              ...
# 68765  88274679        1           Москва
# 68766  88285292        1           Москва
# 68767  84616188     1204           Бердск
# 68768  88277660     1928          Узловая
# 68769  85378686       53        Краснодар
#
#                                                     name test_required  \
# 0      Тестировщик / QA Engineer (Junior / Middle / S...           NaN
# 1            Ведущий Системный Аналитик Kleiber.Graphics           NaN
# 2                                        Бизнес-аналитик           NaN
# 3      Менеджер проектов/Аккаунт-менеджер (IT сфера) ...           NaN
# 4      Специалист службы поддержки (удаленно), Ростов...           NaN
# ...                                                  ...           ...
# 68765  Заместитель технического директора по электрот...           NaN
# 68766  Инженер / Presale по серверному оборудованию и...           NaN
# 68767                                     Программист 1C           NaN
# 68768          Инженер-программист (Промет СЭЗ, Узловая)           NaN
# 68769                             Специалист 1С (стажер)           NaN
#
#        salary_to  salary_from salary_gross salary_currency  address_lat  ...  \
# 0            NaN          NaN          NaN             NaN    59.984924  ...
# 1       250000.0     230000.0        False             RUR          NaN  ...
# 2            NaN          NaN          NaN             NaN          NaN  ...
# 3            NaN          NaN          NaN             NaN    58.004460  ...
# 4            NaN      35000.0         True             RUR          NaN  ...
# ...          ...          ...          ...             ...          ...  ...
# 68765        NaN          NaN          NaN             NaN          NaN  ...
# 68766   300000.0     150000.0        False             RUR    55.714653  ...
# 68767        NaN      80000.0        False             RUR          NaN  ...
# 68768        NaN     130000.0         True             RUR          NaN  ...
# 68769    60000.0      35000.0        False             RUR    45.036330  ...
#
#                 professional_roles_name working_time_modes  \
# 0                           Тестировщик                NaN
# 1                    Системный аналитик                NaN
# 2                              Аналитик                NaN
# 3                 Руководитель проектов                NaN
# 4      Специалист технической поддержки                NaN
# ...                                 ...                ...
# 68765        Технический директор (CTO)                NaN
# 68766  Специалист технической поддержки                NaN
# 68767          Программист, разработчик                NaN
# 68768          Программист, разработчик                NaN
# 68769          Программист, разработчик                NaN
#
#       driver_license_types  working_time_intervals quick_responses_allowed  \
# 0                      NaN                     NaN                   False
# 1                      NaN                     NaN                   False
# 2                      NaN                     NaN                   False
# 3                      NaN                     NaN                   False
# 4                      NaN                     NaN                   False
# ...                    ...                     ...                     ...
# 68765                  NaN                     NaN                   False
# 68766                  NaN                     NaN                   False
# 68767                  NaN                     NaN                   False
# 68768                  NaN                     NaN                   False
# 68769                  NaN                     NaN                   False
#
#       response_letter_required  accept_incomplete_resumes  experience_from  \
# 0                        False                      False              1.0
# 1                        False                      False              NaN
# 2                        False                      False              NaN
# 3                        False                      False              1.0
# 4                        False                      False              NaN
# ...                        ...                        ...              ...
# 68765                    False                      False              6.0
# 68766                    False                      False              1.0
# 68767                    False                      False              NaN
# 68768                    False                      False              NaN
# 68769                    False                      False              NaN
#
#       experience_to no_experience
# 0               3.0         False
# 1               6.0         False
# 2               6.0         False
# 3               3.0         False
# 4               NaN          True
# ...             ...           ...
# 68765           NaN         False
# 68766           3.0         False
# 68767           6.0         False
# 68768           6.0         False
# 68769           NaN          True
#
# [68770 rows x 57 columns]

# %%
data_set_3 = data_set_3.rename(columns=rename_dict)

# %%
data_set_123 = concat_preserve_first_structure(data_set_12, data_set_3)

# %%
data_set_123
# Out:
#           №        id                                              title  \
# 0       1.0  78577559                                    Главный механик
# 1       2.0  78693069                                   HTML-верстальщик
# 2       3.0  78945452    Тренер (направление профессионального обучения)
# 3       4.0  79352008                            Старший механик на КСПГ
# 4       5.0  79406472                             System Analyst Trainee
# ...     ...       ...                                                ...
# 631754  NaN  88274679  Заместитель технического директора по электрот...
# 631755  NaN  88285292  Инженер / Presale по серверному оборудованию и...
# 631756  NaN  84616188                                     Программист 1C
# 631757  NaN  88277660          Инженер-программист (Промет СЭЗ, Узловая)
# 631758  NaN  85378686                             Специалист 1С (стажер)
#
#                                               description  \
# 0       Вакансия компании:   ООО ПК Предприятие "ПИК" ...
# 1       В креативное агентство на полный рабочий день ...
# 2         Наши предложения:        самостоятельность в...
# 3         Обязанности:        _Обеспечение технически ...
# 4       IT-компания Aston - компания по разработке про...
# ...                                                   ...
# 631754  <strong>Обязанности:</strong> <ul> <li>Определ...
# 631755  <p>В 2010 году была создана Группа компаний «<...
# 631756  <strong>Обязанности:</strong> <ul> <li>Участие...
# 631757  <strong>Обязанности:</strong> <ul> <li>Разрабо...
# 631758  <p><strong>Требуется помощник Специалиста техп...
#
#                                                key_skills  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4       UML,SQL,Scrum,Retail,Базы данных,Kanban,Waterf...
# ...                                                   ...
# 631754  {"Разработка проектной документации","Техничес...
# 631755  {"Английский язык","Аналитическое мышление",Мн...
# 631756                                                NaN
# 631757  {"Разработка ПО",CODESYS,STL,Boost,Linux,"Англ...
# 631758  {"Ориентация на результат","1С: Предприятие","...
#
#                      company     location               date_of_post   type  \
# 0                    JCat.ru  Владивосток                 27.03.2023  close
# 1             Чугунова Ирина          NaN                 29.03.2023  close
# 2                Перекрёсток          NaN                 18.04.2023  close
# 3       Газпром гелий сервис          NaN                 17.04.2023  close
# 4                      Aston          NaN                 17.04.2023  close
# ...                      ...          ...                        ...    ...
# 631754                   Эн+       Москва  2023-10-17 11:16:01+03:00    NaN
# 631755                  NSGP       Москва  2023-10-17 13:12:28+03:00    NaN
# 631756            ПК Продсиб       Бердск  2023-10-17 10:35:59+03:00    NaN
# 631757                ПРОМЕТ      Узловая  2023-10-17 11:44:04+03:00    NaN
# 631758             ЭННЕРЛИНК    Краснодар  2023-10-17 09:17:26+03:00    NaN
#
#         salary_from  salary_to currency  experience_from  experience_to  \
# 0          160000.0   160000.0      RUR              6.0            NaN
# 1               NaN        NaN      NaN              1.0            3.0
# 2               NaN        NaN      NaN              1.0            3.0
# 3               NaN        NaN      NaN              6.0            NaN
# 4               NaN        NaN      NaN              NaN            NaN
# ...             ...        ...      ...              ...            ...
# 631754          NaN        NaN      NaN              6.0            NaN
# 631755     150000.0   300000.0      NaN              1.0            3.0
# 631756      80000.0        NaN      NaN              NaN            6.0
# 631757     130000.0        NaN      NaN              NaN            6.0
# 631758      35000.0    60000.0      NaN              NaN            NaN
#
#         no_experience job_type_concrete     schedule
# 0               False  полная занятость  полный день
# 1               False  полная занятость  полный день
# 2               False  полная занятость  полный день
# 3               False  полная занятость  полный день
# 4                True        стажировка  полный день
# ...               ...               ...          ...
# 631754          False  Полная занятость  Полный день
# 631755          False  Полная занятость  Полный день
# 631756          False  Полная занятость  Полный день
# 631757          False  Полная занятость  Полный день
# 631758           True  Полная занятость  Полный день
#
# [631759 rows x 17 columns]

# %% [markdown]
# ## Предобработка

# %% [markdown]
# Предобработаем данные о городе, в котором предлагается работа

# %%
data_set_123['city'] = data_set_123['location'].astype(str).str.split().str[0].str.lower().str.strip('.,;!?г.')

# %% [markdown]
# Предобработаем дату публикации поста

# %%
def convert_date(date_val):
    try:
        # Пробуем преобразовать каждый элемент отдельно
        dt = pd.to_datetime(date_val, format='mixed', dayfirst=True)
        return dt.strftime('%d.%m.%Y')
    except:
        # Если не получается, возвращаем оригинальное значение или пустую строку
        return date_val

data_set_123['date_of_post'] = data_set_123['date_of_post'].apply(convert_date)

# %%
data_set_123['description'].values
# Out:
# array(['Вакансия компании:   ООО ПК Предприятие "ПИК"            Предприятие «ПИК» более 27 лет занимается производством, реализацией, поставкой и монтажом металлических ограждений барьерного типа, рамных опор и других конструкций. Почему с нами стоит работать: Компания на рынке уже более 27 лет. За это время мы стали настоящими лидерами в своей нише  В «ПИК» не существует таких понятий, как низкий уровень дохода, задержки зарплаты и неуважение со стороны коллег/начальства  Наш продукт эксклюзивный и качественный. С ним действительно приятно работать!  Наша компания – это команда профессионалов, готовых всегда прийти на помощь своим коллегам  Мы уважаем и ценим своих сотрудников, поэтому каждого мы оформляем по ТК РФ с полностью белой заработной платой  Наш офис оборудован всем самым необходимым для комфортной работы и непрерывного профессионального развития. Вы активны, амбициозны, желаете и готовы работать и развиваться в стабильной компании с 27 летней историей? Приглашаем вас к нам – в компанию «ПИК»!      Предприятие с крепкой производственной базой, ведущее добычу рассыпного золота, ориентированное на долгосрочный стабильный рост, приглашает на работу Главного механика  Мы ищем человека, который детально знает технику (бульдозеры, фронтальные погрузчики, экскаваторы, самосвалы, вахтовые автомобили, знает как технику обслуживать и ремонтировать, но при этом обладает системным подходом к организации работы службы главного механика, т.е. способен четко ставить задачи и терпеливо, жестко, последовательно добиваться результата с помощью стандартизированных инструментов управления службой (сменные задания, заказ- наряды, чек-листы, бортовые журналы и.т.п.)  Нам нужен руководитель, умеющий управлять и взаимодействовать с людьми, чувствовать людей в условиях высокой сезонной нагрузки, который сможет жестко и четко организовать выполнение следующих блоков задач службы главного механика нашей артели:      Организация выпуска/выпуск техники на смену      Организация исполнения требований эксплуатации техники и прием техники со смены      Организация и проведение регламентного и экстренного обслуживания и ремонта техники      Управление запасами ЗиП и ГСМ (в т.ч. оприходование и списание ЗиП и ГСМ)     Управление закупками ЗиП и ГСМ     Управление персоналом и структурой службы главного механика  Требования:  Нам нужен скрупулезный, въедливый сотрудник, который понимает важность корректно оформленных документов (накладных, журналов и т.п.) и понимает, что всё имущество артели: Техника, ЗиП, ГСМ принадлежат владельцам артели. Мы ищем ответственного человека, который будет стоять на страже бережного отношения к имуществу артели и то же самое будет требовать от себя, своих подчиненных и других сотрудников артели  Мы ищем сверхуниверсала с опытом работы более 8 лет на должности слесаря- механика, из которых не менее 3 лет на должности главного механика или руководителя механизированной колонны на предприятиях, ведущих золотодобычу на рассыпных месторождениях, профессионала который может детально и быстро разобраться в тонкостях деятельности артели, быстро вникнуть в ситуацию и четко выстроить работу службы главного механика  Нам необходим, с одной стороны, опытный специалист, мастер «золотые руки», готовый сам исполнять ремонты техники, в т.ч. сложные, в роли слесаря механика  С другой стороны, нам нужен опытный, внимательный к деталям руководитель. Жесткий, шустрый, способный на сверхусилия, способный организовать службу главного механика артели так чтобы вся техника артели была подготовлена и работала в безостановочном режиме в условиях максимальной ежедневной нагрузки как в добычной, так и в разведывательный сезон. При этом фактические расходы на эксплуатацию и ремонт техники удерживались в границах бюджетных нормативов  Условия:      Место работы 50% на участках добычи, 50% офис предприятия в Хабаровске.     Длительность рабочего дня 12 часов     Длительность испытательного срока 3 месяца     Предприятие предоставляет служебный авто ...
#        'В креативное агентство на полный рабочий день в офисе приглашаем html- верстальщика.    Обязанности:        Создание интернет – баннеров      Подготовка баннеров по ТТ      Знание HTML      Верстка макетов      Подготовка макетов в печать    Требования:          ОПЫТ РАБОТЫ В РЕКЛАМНЫХ АГЕНТСТВАХ        Знание всех современных графических программ      Умение работать с большим объемом материалов, быстро выполнять каждую задачу      Ответственность и соблюдение таймингов      Внимательность к деталям, соблюдение всех бизнес процессов компании      Знание HTML5      Наличие портфолио    Условия:          ПОЛНЫЙ РАБОЧИЙ ДЕНЬ          Офис ул. Мосфильмовская (м. Ломоносовский проспект)        Чай, кофе, печеньки,      Широкий диапазон интересных и сложных задач,      Все условия обсуждаются персонально по результатам тестового задания  ',
#        '  Наши предложения:        самостоятельность в работе и принятии решений     карьерное и профессиональное развитие     стабильная заработная плата: оклад + бонус     гибридный график работы (компенсация разъездного характера работы)     комфортный офис с бесплатной парковкой для сотрудников     скидки на товары и услуги более чем 900 компаний-партнёров     корпоративные скидки для сотрудников X5 Group     страхование жизни и здоровья     расширенный полис ДМС со стоматологией     корпоративная жизнь с праздниками, подарками и мероприятиями    Наши ожидания:        организация и проведение обучения сотрудников-новичков стандартам и технологиям работы с товаром в соответствии с утверждённой программой     контроль качества усвоения знаний     сопровождение новичков на этапе адаптации     проведение дополнительных занятий и вебинаров с работающими сотрудниками по нововведениям и типичным ошибкам     подготовка методических и учебных материалов     посещение магазинов с целью оценки качества выполнения технологий и стандартов работы компании,     обучение на практике  ',
#        ...,
#        '<strong>Обязанности:</strong> <ul> <li>Участие во внедрении.</li> <li>Полное сопровождение баз данных на платформе 1С 8.3: ERP2, Розница 2.3, Управление Торговлей 11.4, Зарплата и управление персоналом 3.1, Бухгалтерия Предприятия 3.0 (администрирование, разработка и доработка нетиповых конфигураций, применение техники оптимизации программного кода, написание отчетов, создание обработок и т.п; поддержка пользователей).</li> <li>Интеграция 1С с внешними ИС: ЕГАИС, Меркурий, ЧЗ.</li> <li>Интеграция 1С с провайдерами ЭДО.</li> <li>Интеграция 1С с кассовым оборудованием, весами, ТСД.</li> <li>Составления технической документации</li> </ul> <p><strong>Требования:</strong></p> <ul> <li>Высшее техническое образование (в сфере информационных технологий, математики, физики)</li> <li>Стаж работы: 3-6 лет.</li> <li>Навыки программирования на встроенном языке 1С 8.3</li> <li>Знание типовых конфигураций на платформе 1С 8.3</li> <li>Опыт доработки конфигураций</li> <li>Знание бухгалтерского учета на уровне счетов и проводок, понимание механизма отражения фактов хозяйственных операций в системах бухгалтерского и управленческого учета.</li> <li>знание технологий обмена COM, XML, веб-сервисы</li> </ul> <p><strong>Условия:</strong></p> <ul> <li>Официальное трудоустройство.</li> <li>График работы: 5/2</li> <li>Своевременная и официальная выплата заработной платы 2 раза в месяц.</li> <li>Работа в крупной, стабильной, развивающейся компании.</li> <li>Хорошее, современное рабочее место.</li> <li>Профессиональный и карьерный рост</li> <li>Заработная плата не окончательная устанавливается по результатам собеседования.</li> </ul>',
#        '<strong>Обязанности:</strong> <ul> <li>Разработка и программирование обеспечения на С/С++;</li> <li>Развитие имеющихся программных решений, добавление нового функционала;</li> <li>Участие в проектировании и разработке архитектуры ПО;</li> <li>Проведение энергетических и электротехнических расчетов;</li> <li>Участие в производстве промышленных образцов и запуске серийных продуктов;</li> <li>Поиск новых технических решений, способствующих повышению технологичности изделий и снижению издержек;</li> </ul> <strong>Требования:</strong> <ul> <li>Высшее техническое образование;</li> <li>Уверенное знание С/С++, библиотек STL, boost. Опыт работы с Qt5+;</li> <li>Опыт создания многопоточных приложений;</li> <li>Опыт отладки многопоточных сетевых приложений;</li> <li>Опыт отладки многопоточных сетевых приложений с клиент-серверной архитектурой;</li> <li>Опыт работы в OC Linux на базовом уровне (работа с Shell/Bash, развертка среды разработки);</li> <li>Опыт кроссплатформенной сборки и отладки приложений;</li> <li>Общие знания по электронике, механике;</li> <li>Английский язык (чтение технической документации)</li> </ul> <p><strong>Приветствуется:</strong></p> <ul> <li>Опыт работы с Make/CMake;</li> <li>Дополнительное знание-C#Delphi/Phyton/Golang/Ruby;</li> <li>Опыт работы с промышленными контролерами на базе Codesys.</li> </ul> <strong>Условия:</strong> <ul> <li>Крупное, современное экспортно–ориентированное, стабильно работающее производственное предприятие;</li> <li>Расположение: Особая экономическая зона промышленно-производственного типа Узловая;</li> <li>Оформление в соответствии с ТК РФ;</li> <li>График работы: 5/2 - 8-00 до 16-30;</li> <li>Официальная заработная плата;</li> <li>Возможность профессионального и карьерного роста;</li> <li>Программы обучения в рамках предприятия (Kaizen, PokaYoke)</li> <li>Корпоративный транспорт( г. Узловая, п. Дубовка, г. Новомосковск, г. Донской)</li> <li>Льготное питание;</li> <li>Бесплатное прохождение медосмотра.</li> </ul>',
#        '<p><strong>Требуется помощник Специалиста техподдержки 1С.</strong></p> <ul> <li>Среднее, средне специальное образование или высшее/неоконченное высшее.</li> </ul> <p> </p> <p><strong>Чем предстоит заниматься:</strong></p> <ul> <li>поддержка 1С Предприятие;</li> <li>прием звонков, регистрация и выполнение заявок от пользователей;</li> <li>направление вопросов на специалистов отдела разработки ПО и отслеживание сроков выполнения.</li> <li>помощь специалистам по разработке и сопровождению.</li> </ul> <p> </p> <p><strong>Мы предлагаем:</strong></p> <ul> <li>графики работы - пятидневная рабочая неделя(с периодическими дежурствами),<br />либо посменный график рабочего времени(дневные / ночные смены) - на выбор;</li> <li>переработки приветствуются и влияют на уровень оплаты труда;</li> <li>конкурентная заработная плата. Своевременная выплата 2 раза в месяц. Уровень заработной платы обсуждается на собеседовании индивидуально;<br /></li> </ul> <p><br /><br />Неоспоримыми Вашими преимуществами при рассмотрении вакансии являются:<br />- наличие опыта работы по сопровождению 1С Предприятие или<br />- самостоятельная подготовка: прохождение Вами курсов по 1С Предприятие.</p> <p><br /><br /><strong>Для нас важно:</strong></p> <ul> <li>Желание помогать людям</li> <li>Знание основ 1С Предприятие и желание развиваться в сфере 1С</li> <li>Работа в команде</li> <li>Ориентация на результат</li> <li>Деловое общение</li> <li>Грамотная речь</li> <li>Ведение переговоров</li> <li>Пользователь ПК</li> <li>Работа в режиме многозадачности.<br /><br />Если есть потенциал и нацеленность на результат - Добро пожаловать в нашу команду!</li> </ul>'],
#       dtype=object)

# %%
from bs4 import BeautifulSoup


def remove_html(html_text):
    if pd.isna(html_text):
        return html_text
    soup = BeautifulSoup(html_text, 'html.parser')
    return soup.get_text(separator=' ', strip=True)

# Применяем к колонке
data_set_123['description_clean'] = data_set_123['description'].apply(remove_html)
# Out:
# /var/folders/lk/c663_dk55yb69cnx4blm8wqr0000gn/T/ipykernel_92192/3068500026.py:7: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(html_text, 'html.parser')

# %%
data_set_123
# Out:
#           №        id                                              title  \
# 0       1.0  78577559                                    Главный механик
# 1       2.0  78693069                                   HTML-верстальщик
# 2       3.0  78945452    Тренер (направление профессионального обучения)
# 3       4.0  79352008                            Старший механик на КСПГ
# 4       5.0  79406472                             System Analyst Trainee
# ...     ...       ...                                                ...
# 631754  NaN  88274679  Заместитель технического директора по электрот...
# 631755  NaN  88285292  Инженер / Presale по серверному оборудованию и...
# 631756  NaN  84616188                                     Программист 1C
# 631757  NaN  88277660          Инженер-программист (Промет СЭЗ, Узловая)
# 631758  NaN  85378686                             Специалист 1С (стажер)
#
#                                               description  \
# 0       Вакансия компании:   ООО ПК Предприятие "ПИК" ...
# 1       В креативное агентство на полный рабочий день ...
# 2         Наши предложения:        самостоятельность в...
# 3         Обязанности:        _Обеспечение технически ...
# 4       IT-компания Aston - компания по разработке про...
# ...                                                   ...
# 631754  <strong>Обязанности:</strong> <ul> <li>Определ...
# 631755  <p>В 2010 году была создана Группа компаний «<...
# 631756  <strong>Обязанности:</strong> <ul> <li>Участие...
# 631757  <strong>Обязанности:</strong> <ul> <li>Разрабо...
# 631758  <p><strong>Требуется помощник Специалиста техп...
#
#                                                key_skills  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4       UML,SQL,Scrum,Retail,Базы данных,Kanban,Waterf...
# ...                                                   ...
# 631754  {"Разработка проектной документации","Техничес...
# 631755  {"Английский язык","Аналитическое мышление",Мн...
# 631756                                                NaN
# 631757  {"Разработка ПО",CODESYS,STL,Boost,Linux,"Англ...
# 631758  {"Ориентация на результат","1С: Предприятие","...
#
#                      company     location date_of_post   type  salary_from  \
# 0                    JCat.ru  Владивосток   27.03.2023  close     160000.0
# 1             Чугунова Ирина          NaN   29.03.2023  close          NaN
# 2                Перекрёсток          NaN   18.04.2023  close          NaN
# 3       Газпром гелий сервис          NaN   17.04.2023  close          NaN
# 4                      Aston          NaN   17.04.2023  close          NaN
# ...                      ...          ...          ...    ...          ...
# 631754                   Эн+       Москва   17.10.2023    NaN          NaN
# 631755                  NSGP       Москва   17.10.2023    NaN     150000.0
# 631756            ПК Продсиб       Бердск   17.10.2023    NaN      80000.0
# 631757                ПРОМЕТ      Узловая   17.10.2023    NaN     130000.0
# 631758             ЭННЕРЛИНК    Краснодар   17.10.2023    NaN      35000.0
#
#         salary_to currency  experience_from  experience_to  no_experience  \
# 0        160000.0      RUR              6.0            NaN          False
# 1             NaN      NaN              1.0            3.0          False
# 2             NaN      NaN              1.0            3.0          False
# 3             NaN      NaN              6.0            NaN          False
# 4             NaN      NaN              NaN            NaN           True
# ...           ...      ...              ...            ...            ...
# 631754        NaN      NaN              6.0            NaN          False
# 631755   300000.0      NaN              1.0            3.0          False
# 631756        NaN      NaN              NaN            6.0          False
# 631757        NaN      NaN              NaN            6.0          False
# 631758    60000.0      NaN              NaN            NaN           True
#
#        job_type_concrete     schedule         city  \
# 0       полная занятость  полный день  владивосток
# 1       полная занятость  полный день          nan
# 2       полная занятость  полный день          nan
# 3       полная занятость  полный день          nan
# 4             стажировка  полный день          nan
# ...                  ...          ...          ...
# 631754  Полная занятость  Полный день       москва
# 631755  Полная занятость  Полный день       москва
# 631756  Полная занятость  Полный день       бердск
# 631757  Полная занятость  Полный день      узловая
# 631758  Полная занятость  Полный день    краснодар
#
#                                         description_clean
# 0       Вакансия компании:   ООО ПК Предприятие "ПИК" ...
# 1       В креативное агентство на полный рабочий день ...
# 2       Наши предложения:        самостоятельность в р...
# 3       Обязанности:        _Обеспечение технически пр...
# 4       IT-компания Aston - компания по разработке про...
# ...                                                   ...
# 631754  Обязанности: Определение технической политики,...
# 631755  В 2010 году была создана Группа компаний « НАН...
# 631756  Обязанности: Участие во внедрении. Полное сопр...
# 631757  Обязанности: Разработка и программирование обе...
# 631758  Требуется помощник Специалиста техподдержки 1С...
#
# [631759 rows x 19 columns]

# %%
data_set_123.to_csv('data_combined')

# %%
def show_missing_percentage(df):
    """
    Выводит процент пропущенных значений для каждого столбца
    """
    total_rows = len(df)
    missing_percent = (df.isnull().sum() / total_rows) * 100
    
    print("Процент пропущенных значений по столбцам:")
    print("-" * 50)
    for col, percent in missing_percent.items():
        print(f"{col}: {percent:.2f}%")
    
    return missing_percent

# Использование
missing_percent = show_missing_percentage(data_set_123)
# Out:
# Процент пропущенных значений по столбцам:
# --------------------------------------------------
# №: 11.04%
# id: 0.00%
# title: 0.00%
# description: 0.00%
# key_skills: 37.78%
# company: 0.00%
# location: 34.68%
# date_of_post: 0.00%
# type: 10.89%
# salary_from: 39.07%
# salary_to: 69.78%
# currency: 43.30%
# experience_from: 47.45%
# experience_to: 27.47%
# no_experience: 0.00%
# job_type_concrete: 0.00%
# schedule: 0.16%
# city: 0.00%
# description_clean: 0.00%

# %%
# !pip install natasha
# Out:
# Requirement already satisfied: natasha in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (1.6.0)
# Requirement already satisfied: pymorphy2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from natasha) (0.9.1)
# Requirement already satisfied: razdel>=0.5.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from natasha) (0.5.0)
# Requirement already satisfied: navec>=0.9.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from natasha) (0.10.0)
# Requirement already satisfied: slovnet>=0.6.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from natasha) (0.6.0)
# Requirement already satisfied: yargy>=0.16.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from natasha) (0.16.0)
# Requirement already satisfied: ipymarkup>=0.8.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from natasha) (0.9.0)
# Requirement already satisfied: intervaltree>=3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ipymarkup>=0.8.0->natasha) (3.1.0)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from navec>=0.9.0->natasha) (1.25.1)
# Requirement already satisfied: dawg-python>=0.7.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pymorphy2->natasha) (0.7.2)
# Requirement already satisfied: pymorphy2-dicts-ru<3.0,>=2.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pymorphy2->natasha) (2.4.417127.4579844)
# Requirement already satisfied: docopt>=0.6 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pymorphy2->natasha) (0.6.2)
# Requirement already satisfied: sortedcontainers<3.0,>=2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from intervaltree>=3->ipymarkup>=0.8.0->natasha) (2.4.0)
#
# [notice] A new release of pip is available: 24.1.2 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %%
def extract_modified_first_word(text):
    """
    Извлекает первое слово, пропуская слова с определенными окончаниями.
    
    Args:
        text (str): Входная строка
        
    Returns:
        str: Первое подходящее слово или пустая строка
    """
    if pd.isna(text) or not isinstance(text, str) or not text.strip():
        return ""
    
    # Разбиваем строку на слова (учитываем кириллицу и дефисы)
    words = re.findall(r'[а-яА-ЯёЁa-zA-Z\-]+', text)
    
    if not words:
        return ""
    
    # Слова-исключения, которые нужно возвращать даже с "запрещенными" окончаниями
    exceptions = {
        'военнослужащий', 'военнослужащая', 'техслужащая',
        'заведующий', 'заведующая',
        'полицейский', 'полицейская',
        'управляющий', 'управляющая',
        'вожатый', 'вожатая',
        'разнорабочий', 'разнорабочая', 'горничная',
        'ведущий', 'ведущая', 'госслужащий', 
        'грузчик-комплектовщик-разнорабочий', 'грузчик-разнорабочий',
        'оперуполномоченный', 'мастер-пожарный', 'педагог-вожатый',
        'пожарный', 'управление', 'посыльный', 'ценообразование', 'оператор-разнорабочий', 'analyst', 'scientist', 'сторож-разнорабочий',
        'рабочий', 'горнорабочий', 'дворник-разнорабочий', 'дежурный', 'администратор-горничная', 'строитель-разнорабочий'
    }
    
    # Окончания, которые нужно пропускать
    skip_endings = [
        'ий', 'ая', 'ый', 'яя', 'ое', 'ее', 'ые', 'ие'
    ]
    
    # Проверяем первое слово
    first_word = words[0].lower()
    
    # Если первое слово является исключением - возвращаем его
    if first_word in exceptions:
        return words[0]
    
    # НОВОЕ УСЛОВИЕ: если слово содержит "рабочий" - возвращаем его
    if 'рабочий' in first_word or 'рабочая' in first_word:
        return words[0].lower()

    # Проверяем окончание первого слова
    has_skip_ending = any(first_word.endswith(ending) for ending in skip_endings)
    
    if not has_skip_ending:
        # Если нет "запрещенного" окончания - возвращаем первое слово
        return words[0].lower()
    else:
        # Если есть "запрещенное" окончание - возвращаем второе слово (если есть)
        return words[1].lower() if len(words) > 1 else ""

# %%
data_set_123['title_key'] = data_set_123['title'].apply(extract_modified_first_word)

# %%
data_set_123
# Out:
#           №        id                                              title  \
# 0       1.0  78577559                                    Главный механик
# 1       2.0  78693069                                   HTML-верстальщик
# 2       3.0  78945452    Тренер (направление профессионального обучения)
# 3       4.0  79352008                            Старший механик на КСПГ
# 4       5.0  79406472                             System Analyst Trainee
# ...     ...       ...                                                ...
# 631754  NaN  88274679  Заместитель технического директора по электрот...
# 631755  NaN  88285292  Инженер / Presale по серверному оборудованию и...
# 631756  NaN  84616188                                     Программист 1C
# 631757  NaN  88277660          Инженер-программист (Промет СЭЗ, Узловая)
# 631758  NaN  85378686                             Специалист 1С (стажер)
#
#                                               description  \
# 0       Вакансия компании:   ООО ПК Предприятие "ПИК" ...
# 1       В креативное агентство на полный рабочий день ...
# 2         Наши предложения:        самостоятельность в...
# 3         Обязанности:        _Обеспечение технически ...
# 4       IT-компания Aston - компания по разработке про...
# ...                                                   ...
# 631754  <strong>Обязанности:</strong> <ul> <li>Определ...
# 631755  <p>В 2010 году была создана Группа компаний «<...
# 631756  <strong>Обязанности:</strong> <ul> <li>Участие...
# 631757  <strong>Обязанности:</strong> <ul> <li>Разрабо...
# 631758  <p><strong>Требуется помощник Специалиста техп...
#
#                                                key_skills  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4       UML,SQL,Scrum,Retail,Базы данных,Kanban,Waterf...
# ...                                                   ...
# 631754  {"Разработка проектной документации","Техничес...
# 631755  {"Английский язык","Аналитическое мышление",Мн...
# 631756                                                NaN
# 631757  {"Разработка ПО",CODESYS,STL,Boost,Linux,"Англ...
# 631758  {"Ориентация на результат","1С: Предприятие","...
#
#                      company     location date_of_post   type  salary_from  \
# 0                    JCat.ru  Владивосток   27.03.2023  close     160000.0
# 1             Чугунова Ирина          NaN   29.03.2023  close          NaN
# 2                Перекрёсток          NaN   18.04.2023  close          NaN
# 3       Газпром гелий сервис          NaN   17.04.2023  close          NaN
# 4                      Aston          NaN   17.04.2023  close          NaN
# ...                      ...          ...          ...    ...          ...
# 631754                   Эн+       Москва   17.10.2023    NaN          NaN
# 631755                  NSGP       Москва   17.10.2023    NaN     150000.0
# 631756            ПК Продсиб       Бердск   17.10.2023    NaN      80000.0
# 631757                ПРОМЕТ      Узловая   17.10.2023    NaN     130000.0
# 631758             ЭННЕРЛИНК    Краснодар   17.10.2023    NaN      35000.0
#
#         salary_to currency  experience_from  experience_to  no_experience  \
# 0        160000.0      RUR              6.0            NaN          False
# 1             NaN      NaN              1.0            3.0          False
# 2             NaN      NaN              1.0            3.0          False
# 3             NaN      NaN              6.0            NaN          False
# 4             NaN      NaN              NaN            NaN           True
# ...           ...      ...              ...            ...            ...
# 631754        NaN      NaN              6.0            NaN          False
# 631755   300000.0      NaN              1.0            3.0          False
# 631756        NaN      NaN              NaN            6.0          False
# 631757        NaN      NaN              NaN            6.0          False
# 631758    60000.0      NaN              NaN            NaN           True
#
#        job_type_concrete     schedule         city  \
# 0       полная занятость  полный день  владивосток
# 1       полная занятость  полный день          nan
# 2       полная занятость  полный день          nan
# 3       полная занятость  полный день          nan
# 4             стажировка  полный день          nan
# ...                  ...          ...          ...
# 631754  Полная занятость  Полный день       москва
# 631755  Полная занятость  Полный день       москва
# 631756  Полная занятость  Полный день       бердск
# 631757  Полная занятость  Полный день      узловая
# 631758  Полная занятость  Полный день    краснодар
#
#                                         description_clean            title_key
# 0       Вакансия компании:   ООО ПК Предприятие "ПИК" ...              механик
# 1       В креативное агентство на полный рабочий день ...     html-верстальщик
# 2       Наши предложения:        самостоятельность в р...               тренер
# 3       Обязанности:        _Обеспечение технически пр...              механик
# 4       IT-компания Aston - компания по разработке про...               system
# ...                                                   ...                  ...
# 631754  Обязанности: Определение технической политики,...          заместитель
# 631755  В 2010 году была создана Группа компаний « НАН...              инженер
# 631756  Обязанности: Участие во внедрении. Полное сопр...          программист
# 631757  Обязанности: Разработка и программирование обе...  инженер-программист
# 631758  Требуется помощник Специалиста техподдержки 1С...           специалист
#
# [631759 rows x 20 columns]

# %%
def calculate_group_adjustment_coefficients(df, value_column, group_column, result_column='coefficient'):
    """
    Рассчитывает коэффициенты для групп относительно общего среднего.
    
    Args:
        df (pd.DataFrame): Исходный DataFrame
        value_column (str): Название столбца с числовыми значениями
        group_column (str): Название столбца с группирующей переменной
        result_column (str): Название столбца для коэффициентов
        
    Returns:
        pd.DataFrame: DataFrame с добавленным столбцом коэффициентов
    """
    result_df = df.copy()
    
    # Рассчитываем общее среднее по всему столбцу
    overall_mean = result_df[value_column].mean()
    print(f"Общее среднее по столбцу '{value_column}': {overall_mean:.2f}")
    
    # Рассчитываем средние значения по группам
    group_means = result_df.groupby(group_column)[value_column].mean()
    print("Средние по группам:")
    print(group_means)
    
    # Рассчитываем коэффициенты: среднее_по_группе / общее_среднее
    # Каждому значению в группе присваивается коэффициент его группы
    result_df[result_column] = result_df[group_column].map(group_means / overall_mean)
    
    return result_df

# %%
data_set_123_coeffs = calculate_group_adjustment_coefficients(data_set_123, 'salary_from', 'company', 'salary_from_company_coefficient')
# Out:
# Общее среднее по столбцу 'salary_from': 103843.92
# Средние по группам:
# company
#  DANTONE HOME                      110000.000000
#  L P H                              48000.000000
#  ЗАВОД КриалЭнергоСтрой             86636.363636
#  Хоум Отель                                  NaN
#  Центр развития персонала Успех     80000.000000
#                                        ...
# “Объединенные сети”                  1500.000000
# “РемСпецМаш“                        50000.000000
# ”ASI mart “                        180000.000000
# №14 ЕМДЕУ ОРТАЛЫҒЫ                 100000.000000
# ❗️Gaming Trade❗️                    35000.000000
# Name: salary_from, Length: 141247, dtype: float64

# %%
data_set_123_coeffs
# Out:
#           №        id                                              title  \
# 0       1.0  78577559                                    Главный механик
# 1       2.0  78693069                                   HTML-верстальщик
# 2       3.0  78945452    Тренер (направление профессионального обучения)
# 3       4.0  79352008                            Старший механик на КСПГ
# 4       5.0  79406472                             System Analyst Trainee
# ...     ...       ...                                                ...
# 631754  NaN  88274679  Заместитель технического директора по электрот...
# 631755  NaN  88285292  Инженер / Presale по серверному оборудованию и...
# 631756  NaN  84616188                                     Программист 1C
# 631757  NaN  88277660          Инженер-программист (Промет СЭЗ, Узловая)
# 631758  NaN  85378686                             Специалист 1С (стажер)
#
#                                               description  \
# 0       Вакансия компании:   ООО ПК Предприятие "ПИК" ...
# 1       В креативное агентство на полный рабочий день ...
# 2         Наши предложения:        самостоятельность в...
# 3         Обязанности:        _Обеспечение технически ...
# 4       IT-компания Aston - компания по разработке про...
# ...                                                   ...
# 631754  <strong>Обязанности:</strong> <ul> <li>Определ...
# 631755  <p>В 2010 году была создана Группа компаний «<...
# 631756  <strong>Обязанности:</strong> <ul> <li>Участие...
# 631757  <strong>Обязанности:</strong> <ul> <li>Разрабо...
# 631758  <p><strong>Требуется помощник Специалиста техп...
#
#                                                key_skills  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4       UML,SQL,Scrum,Retail,Базы данных,Kanban,Waterf...
# ...                                                   ...
# 631754  {"Разработка проектной документации","Техничес...
# 631755  {"Английский язык","Аналитическое мышление",Мн...
# 631756                                                NaN
# 631757  {"Разработка ПО",CODESYS,STL,Boost,Linux,"Англ...
# 631758  {"Ориентация на результат","1С: Предприятие","...
#
#                      company     location date_of_post   type  salary_from  \
# 0                    JCat.ru  Владивосток   27.03.2023  close     160000.0
# 1             Чугунова Ирина          NaN   29.03.2023  close          NaN
# 2                Перекрёсток          NaN   18.04.2023  close          NaN
# 3       Газпром гелий сервис          NaN   17.04.2023  close          NaN
# 4                      Aston          NaN   17.04.2023  close          NaN
# ...                      ...          ...          ...    ...          ...
# 631754                   Эн+       Москва   17.10.2023    NaN          NaN
# 631755                  NSGP       Москва   17.10.2023    NaN     150000.0
# 631756            ПК Продсиб       Бердск   17.10.2023    NaN      80000.0
# 631757                ПРОМЕТ      Узловая   17.10.2023    NaN     130000.0
# 631758             ЭННЕРЛИНК    Краснодар   17.10.2023    NaN      35000.0
#
#         ...  currency experience_from  experience_to  no_experience  \
# 0       ...       RUR             6.0            NaN          False
# 1       ...       NaN             1.0            3.0          False
# 2       ...       NaN             1.0            3.0          False
# 3       ...       NaN             6.0            NaN          False
# 4       ...       NaN             NaN            NaN           True
# ...     ...       ...             ...            ...            ...
# 631754  ...       NaN             6.0            NaN          False
# 631755  ...       NaN             1.0            3.0          False
# 631756  ...       NaN             NaN            6.0          False
# 631757  ...       NaN             NaN            6.0          False
# 631758  ...       NaN             NaN            NaN           True
#
#         job_type_concrete     schedule         city  \
# 0        полная занятость  полный день  владивосток
# 1        полная занятость  полный день          nan
# 2        полная занятость  полный день          nan
# 3        полная занятость  полный день          nan
# 4              стажировка  полный день          nan
# ...                   ...          ...          ...
# 631754   Полная занятость  Полный день       москва
# 631755   Полная занятость  Полный день       москва
# 631756   Полная занятость  Полный день       бердск
# 631757   Полная занятость  Полный день      узловая
# 631758   Полная занятость  Полный день    краснодар
#
#                                         description_clean  \
# 0       Вакансия компании:   ООО ПК Предприятие "ПИК" ...
# 1       В креативное агентство на полный рабочий день ...
# 2       Наши предложения:        самостоятельность в р...
# 3       Обязанности:        _Обеспечение технически пр...
# 4       IT-компания Aston - компания по разработке про...
# ...                                                   ...
# 631754  Обязанности: Определение технической политики,...
# 631755  В 2010 году была создана Группа компаний « НАН...
# 631756  Обязанности: Участие во внедрении. Полное сопр...
# 631757  Обязанности: Разработка и программирование обе...
# 631758  Требуется помощник Специалиста техподдержки 1С...
#
#                   title_key salary_from_company_coefficient
# 0                   механик                        0.656560
# 1          html-верстальщик                        0.409268
# 2                    тренер                        0.649648
# 3                   механик                             NaN
# 4                    system                        3.851935
# ...                     ...                             ...
# 631754          заместитель                             NaN
# 631755              инженер                        1.925967
# 631756          программист                        0.394823
# 631757  инженер-программист                        0.791971
# 631758           специалист                        0.365934
#
# [631759 rows x 21 columns]

# %%
data_set_123_coeffs = calculate_group_adjustment_coefficients(data_set_123_coeffs, 'salary_to', 'company', 'salary_to_company_coefficient')
# Out:
# Общее среднее по столбцу 'salary_to': 182231.58
# Средние по группам:
# company
#  DANTONE HOME                      200000.0
#  L P H                              58000.0
#  ЗАВОД КриалЭнергоСтрой             82500.0
#  Хоум Отель                             NaN
#  Центр развития персонала Успех     85000.0
#                                      ...
# “Объединенные сети”                     NaN
# “РемСпецМаш“                            NaN
# ”ASI mart “                        360000.0
# №14 ЕМДЕУ ОРТАЛЫҒЫ                 150000.0
# ❗️Gaming Trade❗️                        NaN
# Name: salary_to, Length: 141247, dtype: float64

# %%
data_set_123_coeffs = calculate_group_adjustment_coefficients(data_set_123_coeffs, 'salary_from', 'title_key', 'salary_from_title_coefficient')
# Out:
# Общее среднее по столбцу 'salary_from': 103843.92
# Средние по группам:
# title_key
#                   64885.294118
# -                156333.333333
# -d               200000.000000
# -zj               90000.000000
# -специалист       40000.000000
#                      ...
# юрист-эксперт              NaN
# юриста            30000.000000
# юристконсульт    531368.000000
# язык              80000.000000
# яндекс            30000.000000
# Name: salary_from, Length: 7817, dtype: float64

# %%
data_set_123_coeffs = calculate_group_adjustment_coefficients(data_set_123_coeffs, 'salary_to', 'title_key', 'salary_to_title_coefficient')
# Out:
# Общее среднее по столбцу 'salary_to': 182231.58
# Средние по группам:
# title_key
#                  112000.0
# -                 70000.0
# -d               177000.0
# -zj              110000.0
# -специалист       50000.0
#                    ...
# юрист-эксперт         NaN
# юриста            40000.0
# юристконсульт     65923.0
# язык                  NaN
# яндекс                NaN
# Name: salary_to, Length: 7817, dtype: float64

# %%
data_set_123_coeffs['salary_from_filled'] = data_set_123_coeffs['salary_from']

# %%
data_set_123_coeffs.to_csv('data_set_123_coeffs.csv')

# %% [markdown]
# Преобразуем данные в столбце date_of_post так, чтобы получить данные о том, в каком месяце был сделан пост.

# %%
data_set_123_coeffs['month'] = pd.to_datetime(data_set_123_coeffs['date_of_post']).dt.month
# Out:
# /var/folders/lk/c663_dk55yb69cnx4blm8wqr0000gn/T/ipykernel_92192/1866043971.py:1: UserWarning: Parsing dates in %d.%m.%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   data_set_123_coeffs['month'] = pd.to_datetime(data_set_123_coeffs['date_of_post']).dt.month

# %% [markdown]
# ## Удаление пропусков из датафрейма по условию наличия пропуска в столбце salary_from

# %%
def convert_all_string_columns_to_lowercase(df):
    """
    Автоматически находит все строковые колонки и переводит их в нижний регистр
    """
    df_copy = df.copy()
    
    string_columns = df_copy.select_dtypes(include=['object', 'string']).columns
    
    print(f"Найдено строковых колонок: {list(string_columns)}")
    
    for col in string_columns:
        if df_copy[col].dtype == 'object':
            df_copy[col] = df_copy[col].apply(
                lambda x: x.lower() if pd.notna(x) and isinstance(x, str) else x
            )
        else:
            df_copy[col] = df_copy[col].str.lower()
    
    return df_copy

# %%
data_set_123_coeffs_lower = convert_all_string_columns_to_lowercase(data_set_123_coeffs)
# Out:
# Найдено строковых колонок: ['title', 'description', 'key_skills', 'company', 'location', 'date_of_post', 'type', 'currency', 'job_type_concrete', 'schedule', 'city', 'description_clean', 'title_key']

# %% [markdown]
# Уберем строки с пропущенной целевой переменной

# %%
data_set_123_clean_salary = data_set_123_coeffs_lower.dropna(subset=['salary_from'])

# %% [markdown]
# Удаление из датафрейма всех наблюдений с нероссийской валютой

# %%
data_set_123_clean_salary = data_set_123_clean_salary[data_set_123_clean_salary['currency'] == 'rur']

# %% [markdown]
# Также удалим все строки, в которых город не российский. Такое известно по круйней мере про Ташкент. Удаление необходимо, потому что для этой строки, видимо, неверно закодировано значение currency.

# %%
data_set_123_clean_salary = data_set_123_clean_salary[data_set_123_clean_salary['city'] != 'ташкент']

# %% [markdown]
# ## Разведочный анализ данных

# %% [markdown]
# Удалим все дубликаты:

# %%
data_set_123_clean_salary['city'].value_counts()
# Out:
# city
# nan               118526
# москва             40296
# санкт-петербур     20318
# екатеринбур         7418
# новосибирск         5560
#                    ...
# сосково                1
# полтавская             1
# задонск                1
# чик                    1
# лохино                 1
# Name: count, Length: 2851, dtype: int64

# %%
data_set_123_clean_salary.drop_duplicates(inplace=True)

# %% [markdown]
# Оценим датасет в общих чертах:

# %%
data_set_123_clean_salary.describe(include='all').T
# Out:
#                                     count  unique  \
# №                                331930.0     NaN
# id                               332054.0     NaN
# title                              332054  118028
# description                        332054  278186
# key_skills                         205167  150832
# company                            332054   96263
# location                           213528   89483
# date_of_post                       332054     111
# type                               332054       4
# salary_from                      332054.0     NaN
# salary_to                        158012.0     NaN
# currency                           332054       1
# experience_from                  173590.0     NaN
# experience_to                    226397.0     NaN
# no_experience                      332054       2
# job_type_concrete                  332054       5
# schedule                           331930       5
# city                               332054    2851
# description_clean                  332054  277952
# title_key                          332054    5142
# salary_from_company_coefficient  332054.0     NaN
# salary_to_company_coefficient    265323.0     NaN
# salary_from_title_coefficient    332054.0     NaN
# salary_to_title_coefficient      330057.0     NaN
# salary_from_filled               332054.0     NaN
# month                            332054.0     NaN
#
#                                                                                top  \
# №                                                                              NaN
# id                                                                             NaN
# title                                                                офис-менеджер
# description                        обязанности:        организация и контроль п...
# key_skills                                                        работа в команде
# company                                                                  пятёрочка
# location                                                                    москва
# date_of_post                                                            16.06.2023
# type                                                                         close
# salary_from                                                                    NaN
# salary_to                                                                      NaN
# currency                                                                       rur
# experience_from                                                                NaN
# experience_to                                                                  NaN
# no_experience                                                                False
# job_type_concrete                                                 полная занятость
# schedule                                                               полный день
# city                                                                           nan
# description_clean                обязанности:        организация и контроль при...
# title_key                                                                 менеджер
# salary_from_company_coefficient                                                NaN
# salary_to_company_coefficient                                                  NaN
# salary_from_title_coefficient                                                  NaN
# salary_to_title_coefficient                                                    NaN
# salary_from_filled                                                             NaN
# month                                                                          NaN
#
#                                    freq             mean             std  \
# №                                   NaN    290446.168388   176154.635379
# id                                  NaN  79952252.552741  2573722.238052
# title                              1891              NaN             NaN
# description                         328              NaN             NaN
# key_skills                          977              NaN             NaN
# company                            2531              NaN             NaN
# location                            852              NaN             NaN
# date_of_post                      21128              NaN             NaN
# type                             193050              NaN             NaN
# salary_from                         NaN     67738.574105    46888.117773
# salary_to                           NaN     92965.135806   468908.600811
# currency                         332054              NaN             NaN
# experience_from                     NaN         1.242232        1.073057
# experience_to                       NaN         3.812197        1.333435
# no_experience                    234839              NaN             NaN
# job_type_concrete                313278              NaN             NaN
# schedule                         240511              NaN             NaN
# city                             118526              NaN             NaN
# description_clean                   328              NaN             NaN
# title_key                         26240              NaN             NaN
# salary_from_company_coefficient     NaN         0.661128        0.384689
# salary_to_company_coefficient       NaN         0.524539        0.822163
# salary_from_title_coefficient       NaN           0.9523        0.624027
# salary_to_title_coefficient         NaN         0.958204        0.886582
# salary_from_filled                  NaN     67738.574105    46888.117773
# month                               NaN         4.910262        0.954472
#
#                                         min          25%         50%  \
# №                                       1.0     108286.5    324260.5
# id                               18330133.0  79202222.75  80148048.0
# title                                   NaN          NaN         NaN
# description                             NaN          NaN         NaN
# key_skills                              NaN          NaN         NaN
# company                                 NaN          NaN         NaN
# location                                NaN          NaN         NaN
# date_of_post                            NaN          NaN         NaN
# type                                    NaN          NaN         NaN
# salary_from                             1.0      40000.0     55000.0
# salary_to                               1.0      50000.0     70000.0
# currency                                NaN          NaN         NaN
# experience_from                         0.0          1.0         1.0
# experience_to                           0.0          3.0         3.0
# no_experience                           NaN          NaN         NaN
# job_type_concrete                       NaN          NaN         NaN
# schedule                                NaN          NaN         NaN
# city                                    NaN          NaN         NaN
# description_clean                       NaN          NaN         NaN
# title_key                               NaN          NaN         NaN
# salary_from_company_coefficient     0.00001     0.434513    0.584256
# salary_to_company_coefficient      0.000011     0.312789    0.439002
# salary_from_title_coefficient      0.000481     0.695838    0.802894
# salary_to_title_coefficient        0.000412     0.594028    0.726444
# salary_from_filled                      1.0      40000.0     55000.0
# month                                   3.0          4.0         5.0
#
#                                         75%          max
# №                                 443252.75     561999.0
# id                               81462443.5   87291833.0
# title                                   NaN          NaN
# description                             NaN          NaN
# key_skills                              NaN          NaN
# company                                 NaN          NaN
# location                                NaN          NaN
# date_of_post                            NaN          NaN
# type                                    NaN          NaN
# salary_from                         80000.0    1500000.0
# salary_to                          110000.0  180000000.0
# currency                                NaN          NaN
# experience_from                         1.0          6.0
# experience_to                           6.0          6.0
# no_experience                           NaN          NaN
# job_type_concrete                       NaN          NaN
# schedule                                NaN          NaN
# city                                    NaN          NaN
# description_clean                       NaN          NaN
# title_key                               NaN          NaN
# salary_from_company_coefficient     0.78678    31.730312
# salary_to_company_coefficient      0.631065   109.750461
# salary_from_title_coefficient      1.131793    48.904725
# salary_to_title_coefficient        1.069511   137.188077
# salary_from_filled                  80000.0    1500000.0
# month                                   6.0          9.0

# %% [markdown]
# Оценим взаимосвязи количественных переменных в общих чертах:

# %%
selected_columns = ['salary_from', 'salary_to', 'experience_from', 'experience_to', 'no_experience']
sns.pairplot(data_set_123_clean_salary[selected_columns])
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_stats/counting.py:137: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
#   bin_edges = np.histogram_bin_edges(vals, bins, binrange, weight)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_stats/counting.py:176: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
#   hist, edges = np.histogram(vals, **bin_kws, weights=weights, density=density)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Из приведенного выше графика можно сделать вывод, что нижний порог зарплаты прямо скоррелирован с верхним порогом зарплаты.
# У тех, у кого опыт работы насчитывает более 6 лет, бывает более высокая зарплата, чем у тех, у кого опыт работы соствляет более одного года. Однако, наблюдений о более промежуточных вариантах нет. Кроме того, в вакансиях, требующих опыта работы от 6 лет, в основном предлагается такая же зарплата, как в вакансиях, требующих опыта от 1 года.
# С максимальным допустимым опытом работы аналогичная связь: в вакансиях, требующих до 6 лет опыта работы, встречаются обещания более высокой зарпалвты, чем в вакансиях, предполагающих не более года опыта работы.
# Ожидаемым образом, в вакансиях, не требующих опыта работы, обещания о размере заработной платы, как правило, меньше, чем в вакансиях с требованиями об опыте работы.

# %% [markdown]
# Заполним пропуски в столбце city по значениею в столбце company -- будем записывать в столбец city самый частотный город для этой компании.

# %%
def fill_na_by_most_frequent_per_group(df, column_x, column_y):
    """
    Заполняет пропуски в столбце X самой частотной категорией из X для каждого значения Y
    
    Parameters:
    df - DataFrame
    column_x - столбец с пропусками для заполнения
    column_y - столбец для группировки
    """
    df_copy = df.copy()
    
    # Считаем самые частотные значения
    mode_per_group = df_copy.groupby(column_y)[column_x].apply(
        lambda x: x.mode().iloc[0] if not x.mode().empty else 'nan'
    ).to_dict()
    
    
    # Правильное определение строковых 'nan'
    mask_na = df_copy[column_x] == 'nan'
    
    
    # Заполняем пропуски
    df_copy.loc[mask_na, column_x] = df_copy.loc[mask_na, column_y].map(mode_per_group)

    
    return df_copy

# %%
def fill_na_by_most_frequent_per_group(df, column_x, column_y):
    """
    Заполняет пропуски в столбце X самой частотной категорией из X для каждого значения Y
    Обрабатывает все типы пропусков: настоящие NaN, строки 'nan', пустые строки
    """
    df_copy = df.copy()
    
    print(f"=== ДИАГНОСТИКА ДЛЯ {column_x} ===")
    
    # Определяем ВСЕ типы пропусков
    mask_real_na = df_copy[column_x].isna()
    mask_string_nan = df_copy[column_x] == 'nan'
    mask_empty = df_copy[column_x] == ''
    
    total_na = mask_real_na.sum() + mask_string_nan.sum() + mask_empty.sum()
    print(f"Настоящие NaN: {mask_real_na.sum()}")
    print(f"Строки 'nan': {mask_string_nan.sum()}")
    print(f"Пустые строки: {mask_empty.sum()}")
    print(f"Всего пропусков: {total_na}")
    
    # Создаем временный столбец, где все пропуски заменяем на метку
    temp_x = df_copy[column_x].copy()
    temp_x = temp_x.fillna('_TEMP_NAN_')  # заменяем настоящие NaN
    temp_x = temp_x.replace('nan', '_TEMP_NAN_')  # заменяем строки 'nan'
    temp_x = temp_x.replace('', '_TEMP_NAN_')  # заменяем пустые строки
    
    # Считаем самые частотные значения, игнорируя временные метки
    mode_per_group = df_copy[temp_x != '_TEMP_NAN_'].groupby(column_y)[column_x].apply(
        lambda x: x.mode().iloc[0] if not x.mode().empty else 'unknown'
    ).to_dict()
    
    print(f"\nСамые частотные категории для каждой группы:")
    for y_value, x_mode in list(mode_per_group.items())[:10]:  # покажем первые 10
        print(f"  {column_y}={y_value} -> {column_x}={x_mode}")
    
    # Заполняем ВСЕ типы пропусков
    # 1. Настоящие NaN
    df_copy.loc[mask_real_na, column_x] = df_copy.loc[mask_real_na, column_y].map(mode_per_group)
    
    # 2. Строки 'nan'
    df_copy.loc[mask_string_nan, column_x] = df_copy.loc[mask_string_nan, column_y].map(mode_per_group)
    
    # 3. Пустые строки
    df_copy.loc[mask_empty, column_x] = df_copy.loc[mask_empty, column_y].map(mode_per_group)
    
    # Проверяем результат
    remaining_na = df_copy[column_x].isna().sum()
    remaining_string_nan = (df_copy[column_x] == 'nan').sum()
    remaining_empty = (df_copy[column_x] == '').sum()
    
    print(f"\nПосле заполнения:")
    print(f"Осталось настоящих NaN: {remaining_na}")
    print(f"Осталось строк 'nan': {remaining_string_nan}")
    print(f"Осталось пустых строк: {remaining_empty}")
    
    return df_copy

# %%
data_set_123_clean_salary_nona = fill_na_by_most_frequent_per_group(data_set_123_clean_salary, 'city', 'company')
# Out:
# === ДИАГНОСТИКА ДЛЯ city ===
# Настоящие NaN: 0
# Строки 'nan': 118526
# Пустые строки: 795
# Всего пропусков: 119321
#
# Самые частотные категории для каждой группы:
#   company= dantone home -> city=казань
#   company= l p h  -> city=санкт-петербур
#   company= завод криалэнергострой -> city=казань
#   company= центр развития персонала успех -> city=саранск
#   company=#colorstar studio nail -> city=уфа
#   company=#farш -> city=москва
#   company=#izum -> city=москва
#   company=#lapotok -> city=дзержинск
#   company=#бустораны -> city=ярославль
#   company=#дариподарки -> city=пермь
#
# После заполнения:
# Осталось настоящих NaN: 41284
# Осталось строк 'nan': 0
# Осталось пустых строк: 0

# %%
data_set_123_clean_salary_nona['city'].value_counts()
# Out:
# city
# москва            63873
# санкт-петербур    26548
# екатеринбур       10168
# краснодар          7224
# новосибирск        7029
#                   ...
# высоконские           1
# спутник               1
# романовка             1
# неман                 1
# лохино                1
# Name: count, Length: 2849, dtype: int64

# %% [markdown]
# Перекодируем категориальные переменные, так, чтобы самые частотные значения остались, а остальные -- слились в категорию other. При этом сохраняем такие категрии, у которых наиболее экстримальные значения salary_from -- экстремально высокие и экстремально низкие.

# %%
import pandas as pd
import numpy as np

def recode_categorical_by_frequency(df, column_name, salary_column='salary_from', threshold=0.001):
    """
    Перекодирует категориальную переменную по частотности с обработкой пропущенных значений
    Сохраняет категории, связанные с топ-10 и анти-топ-10 значениями salary_from
    """
    df_copy = df.copy()
    
    # Создаем временную копию столбца, где заменяем NaN на специальное значение
    temp_series = df_copy[column_name].copy()
    temp_series = temp_series.fillna('_MISSING_')
    
    # Считаем частотность каждой категории (включая пропущенные)
    value_counts = temp_series.value_counts(normalize=True)
    
    # Находим категории, которые составляют менее threshold
    rare_categories = value_counts[value_counts < threshold].index
    
    # Находим топ-10 и анти-топ-10 значений salary_from
    top_10_salary = df_copy[salary_column].nlargest(10)
    anti_top_10_salary = df_copy[salary_column].nsmallest(10)
    
    # Получаем индексы строк с экстремальными значениями salary
    extreme_salary_indices = set(top_10_salary.index) | set(anti_top_10_salary.index)
    
    # Получаем категории, которые нужно сохранить (из строк с экстремальными salary)
    categories_to_preserve = set()
    for idx in extreme_salary_indices:
        category_value = df_copy.loc[idx, column_name]
        if pd.notna(category_value) and category_value != 'nan':
            categories_to_preserve.add(category_value)
    
    
    # Заменяем редкие категории на 'other', но сохраняем категории из экстремальных salary
    def recode_value(x, idx):
        if pd.isna(x):
            return np.nan  # Оставляем пропущенные значения как NaN
        elif x in rare_categories and x not in categories_to_preserve:
            return 'other'
        else:
            return x
    
    # Применяем функцию с передачей индекса
    df_copy[column_name] = [recode_value(x, idx) for idx, x in enumerate(df_copy[column_name])]
    
    # Альтернативный способ с apply (менее эффективный, но проще)
    # df_copy[column_name] = df_copy.apply(lambda row: recode_value(row[column_name], row.name), axis=1)
    
    return df_copy

# %%
data_set_123_clean_salary_nona_recoded = recode_categorical_by_frequency(data_set_123_clean_salary_nona, 'company', 'salary_from', 0.001)

# %%
data_set_123_clean_salary_nona_recoded_fully = recode_categorical_by_frequency(data_set_123_clean_salary_nona_recoded, 'city', 'salary_from', 0.01)

# %%
data_set_123_clean_salary_nona_recoded_fully_2 = recode_categorical_by_frequency(data_set_123_clean_salary_nona_recoded_fully, 'title_key', 'salary_from', 0.001)

# %%
data_set_123_clean_salary_nona_recoded_fully_2['title_key'].value_counts()
# Out:
# title_key
# other             54823
# менеджер          26240
# специалист        22971
# инженер           11962
# оператор          10708
#                   ...
# горничная           347
# методист            345
# электромеханик      335
# йога-фитнес           4
# вакансия              2
# Name: count, Length: 149, dtype: int64

# %%
data_set_123_clean_salary_nona_recoded_fully_2.to_csv('data_set_123_clean_salary_nona_recoded_fully_161025.csv')

# %%
def convert_all_string_columns_to_lowercase(df):
    """
    Автоматически находит все строковые колонки и переводит их в нижний регистр
    """
    df_copy = df.copy()
    
    string_columns = df_copy.select_dtypes(include=['object', 'string']).columns
    
    print(f"Найдено строковых колонок: {list(string_columns)}")
    
    for col in string_columns:
        if df_copy[col].dtype == 'object':
            df_copy[col] = df_copy[col].apply(
                lambda x: x.lower() if pd.notna(x) and isinstance(x, str) else x
            )
        else:
            df_copy[col] = df_copy[col].str.lower()
    
    return df_copy

# %%
data_set_123_clean_salary_nona_recoded_fully_2_lower = convert_all_string_columns_to_lowercase(data_set_123_clean_salary_nona_recoded_fully_2)
# Out:
# Найдено строковых колонок: ['title', 'description', 'key_skills', 'company', 'location', 'date_of_post', 'type', 'currency', 'job_type_concrete', 'schedule', 'city', 'description_clean', 'title_key']

# %%
data_set_123_clean_salary_nona_recoded_fully_2_lower.to_csv('data_set_123_clean_salary_nona_recoded_fully_lower_161025.csv')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

def plot_categorical_vertical(df, target_var, cat_vars, figsize=(18, 35)):
    """
    Строит гистограммы одна под другой, показывающие зависимость целевой переменной от категориальных переменных
    
    Parameters:
    df - DataFrame с данными
    target_var - название целевой переменной
    cat_vars - список названий категориальных переменных
    figsize - размер графика
    """
    
    n_vars = len(cat_vars)
    
    # Создаем фигуру с n_vars субплогами в один столбец
    fig, axes = plt.subplots(n_vars, 1, figsize=figsize)
    
    # Если только одна переменная, преобразуем axes в массив
    if n_vars == 1:
        axes = [axes]
    
    # Цветовая палитра
    colors = plt.cm.Set3(np.linspace(0, 1, n_vars))
    
    for i, cat_var in enumerate(cat_vars):
        # Группируем данные по категориальной переменной и считаем среднее целевой переменной
        grouped_data = df.groupby(cat_var)[target_var].mean().sort_values(ascending=False)
        
        # Строим гистограмму
        bars = axes[i].bar(grouped_data.index.astype(str), grouped_data.values, 
                          color=colors[i], alpha=0.7, edgecolor='black')
        
        # Добавляем значения на столбцы
        for bar in bars:
            height = bar.get_height()
            axes[i].text(bar.get_x() + bar.get_width()/2., height + height*0.01,
                       f'{height:.0f}', ha='center', va='bottom', fontsize=9)
        
        # Настройки графика
        axes[i].set_title(f'{target_var} по {cat_var}', fontsize=14, fontweight='bold')
        axes[i].set_xlabel(cat_var, fontsize=12)
        axes[i].set_ylabel(f'Среднее {target_var}', fontsize=12)
        axes[i].tick_params(axis='x', rotation=45)
        axes[i].grid(axis='y', alpha=0.3)
        
        # Добавляем сетку
        axes[i].grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()

# %%
plot_categorical_vertical(data_set_123_clean_salary_nona_recoded_fully_2_lower, 'salary_from', ['city', 'company', 'title_key', 'month', 'schedule', 'job_type_concrete'])

# %% [markdown]
# По составленным гистограммам можно сделать следующие выводы:

# %%
data = (data_set_123_clean_salary['salary_from']).astype(int)

# %%
data
# Out:
# 0         160000
# 5          62000
# 6         130000
# 7          80000
# 8         250000
#            ...
# 562927    200000
# 562945    350000
# 562952    200000
# 562972     90000
# 562988    200000
# Name: salary_from, Length: 332054, dtype: int64

# %%
print("=== АНАЛИЗ ДАННЫХ по столбцу salary_from ===")
print(f"Минимум: {data.min():,.0f}")
print(f"Максимум: {data.max():,.0f}")
print(f"Среднее: {data.mean():,.0f}")
print(f"Медиана: {data.median():,.0f}")
print(f"Стандартное отклонение: {data.std():,.0f}")

# Квартили
print(f"Q1 (25%): {data.quantile(0.25):,.0f}")
print(f"Q2 (50%): {data.quantile(0.50):,.0f}")
print(f"Q3 (75%): {data.quantile(0.75):,.0f}")
print(f"Q95 (95%): {data.quantile(0.95):,.0f}")

# Проверка на выбросы
Q1 = data.quantile(0.25)
Q3 = data.quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = data[(data < lower_bound) | (data > upper_bound)]
print(f"Выбросы: {len(outliers)} значений ({len(outliers)/len(data)*100:.1f}%)")
# Out:
# === АНАЛИЗ ДАННЫХ по столбцу salary_from ===
# Минимум: 1
# Максимум: 1,500,000
# Среднее: 67,739
# Медиана: 55,000
# Стандартное отклонение: 46,888
# Q1 (25%): 40,000
# Q2 (50%): 55,000
# Q3 (75%): 80,000
# Q95 (95%): 150,000
# Выбросы: 21804 значений (6.6%)

# %%
data = data[~data.isin(outliers)]

# %%
plt.figure(figsize=(12, 6))

# KDE plot вместо histplot
sns.kdeplot(data, fill=True, alpha=0.7, color='lightblue')

# Статистические показатели
stats = {
    'Среднее': data.mean(),
    'Медиана': data.median(),
    'Q1': data.quantile(0.25),
    'Q3': data.quantile(0.75)
}

colors = {'Среднее': 'red', 'Медиана': 'green', 'Q1': 'orange', 'Q3': 'orange'}
linestyles = {'Среднее': '--', 'Медиана': '--', 'Q1': ':', 'Q3': ':'}

for name, value in stats.items():
    plt.axvline(value, color=colors[name], linestyle=linestyles[name], 
                linewidth=2, label=f'{name}: {value:.2f}')

plt.xlabel('Значения')
plt.ylabel('Плотность')
plt.title('KDE распределение данных о нижнем пороге зарплаты со статистическими показателями')
plt.legend()
plt.grid(alpha=0.3)
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## One-hot encoding

# %% [markdown]
# Закодируем с помощью one-hot encoding все категориальальные переменные.

# %%
from sklearn.preprocessing import OneHotEncoder

def one_hot_encode_sklearn(df, columns, drop_original=True, sparse=False):
    """
    One-hot кодирование с помощью sklearn OneHotEncoder
    
    Parameters:
    df - DataFrame
    columns - список колонок для кодирования
    drop_original - удалять ли оригинальные колонки
    sparse - возвращать разреженную матрицу (экономит память)
    """
    df_copy = df.copy()
    
    if isinstance(columns, str):
        columns = [columns]
    
    encoder = OneHotEncoder(sparse_output=sparse, drop='first')  # drop='first' чтобы избежать мультиколлинеарности
    
    # Применяем к указанным колонкам
    encoded_array = encoder.fit_transform(df_copy[columns])
    
    # Создаем имена для новых колонок
    feature_names = []
    for i, col in enumerate(columns):
        for category in encoder.categories_[i][1:]:  # пропускаем первую категорию если drop='first'
            feature_names.append(f"{col}_{category}")
    
    # Создаем DataFrame с закодированными признаками
    encoded_df = pd.DataFrame(encoded_array, columns=feature_names, index=df_copy.index)
    
    # Удаляем оригинальные колонки если нужно
    if drop_original:
        df_copy = df_copy.drop(columns, axis=1)
    
    # Объединяем с исходным DataFrame
    df_encoded = pd.concat([df_copy, encoded_df], axis=1)
    
    return df_encoded, encoder

# %%
data_set_123_clean_salary_nona_recoded_fully_2_lower.columns
# Out:
# Index(['№', 'id', 'title', 'description', 'key_skills', 'company', 'location',
#        'date_of_post', 'type', 'salary_from', 'salary_to', 'currency',
#        'experience_from', 'experience_to', 'no_experience',
#        'job_type_concrete', 'schedule', 'city', 'description_clean',
#        'title_key', 'salary_from_company_coefficient',
#        'salary_to_company_coefficient', 'salary_from_title_coefficient',
#        'salary_to_title_coefficient', 'salary_from_filled', 'month'],
#       dtype='object')

# %%
df_one_hot_encoded, encoder = one_hot_encode_sklearn(data_set_123_clean_salary_nona_recoded_fully_2_lower, ['city', 'company', 'job_type_concrete', 'schedule', 'title_key', 'month'])
# Out:
# При выполнении кода в текущей ячейке или предыдущей ячейке ядро аварийно завершило работу. Проверьте код в ячейках, чтобы определить возможную причину сбоя. Щелкните <a href="https://aka.ms/vscodeJupyterKernelCrash">здесь</a> для получения дополнительных сведений. Подробнее см. в <a href='command:jupyter.viewOutput'>журнале Jupyter</a>.

# %%
df_one_hot_encoded.to_csv('df_one_hot_encoded.csv')

# %%
columns_to_drop = ['Unnamed', '№', 'id', 'title', 'description', 'key_skills', 'location', 'date_of_post', 'type', 'salary_to', 'currency', 'description_clean', 'salary_from_company_coefficient','salary_to_company_coefficient', 'salary_from_title_coefficient', 'salary_to_title_coefficient', 'salary_from_filled',]
data_clean = df_one_hot_encoded.drop(columns=columns_to_drop)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/natalialogvinova/Desktop/DS diploma/DS-17 diploma_dataset_preparation.ipynb Ячейка 115 line 2
#       <a href='vscode-notebook-cell:/Users/natalialogvinova/Desktop/DS%20diploma/DS-17%20diploma_dataset_preparation.ipynb#Y222sZmlsZQ%3D%3D?line=0'>1</a> columns_to_drop = ['Unnamed', '№', 'id', 'title', 'description', 'key_skills', 'location', 'date_of_post', 'type', 'salary_to', 'currency', 'description_clean', 'salary_from_company_coefficient','salary_to_company_coefficient', 'salary_from_title_coefficient', 'salary_to_title_coefficient', 'salary_from_filled',]
# ----> <a href='vscode-notebook-cell:/Users/natalialogvinova/Desktop/DS%20diploma/DS-17%20diploma_dataset_preparation.ipynb#Y222sZmlsZQ%3D%3D?line=1'>2</a> data_clean = df_one_hot_encoded.drop(columns=columns_to_drop)
#
# NameError: name 'df_one_hot_encoded' is not defined
